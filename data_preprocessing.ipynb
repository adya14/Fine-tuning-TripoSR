# %%
# %pip install torch torchvision
# %pip install trimesh numpy scipy
# Out:
# Requirement already satisfied: torch in ./TripoSR/venv_name/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torchvision in ./TripoSR/venv_name/lib/python3.10/site-packages (0.17.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: sympy in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: jinja2 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (3.1.3)
# Requirement already satisfied: networkx in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: fsspec in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (2.19.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (4.10.0)
# Requirement already satisfied: triton==2.2.0 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: filelock in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (3.13.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./TripoSR/venv_name/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./TripoSR/venv_name/lib/python3.10/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: numpy in ./TripoSR/venv_name/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./TripoSR/venv_name/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./TripoSR/venv_name/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trimesh in ./TripoSR/venv_name/lib/python3.10/site-packages (4.0.5)
# Requirement already satisfied: numpy in ./TripoSR/venv_name/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scipy in ./TripoSR/venv_name/lib/python3.10/site-packages (1.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import torch
import json
import trimesh
import os
import random
import shutil
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.model_selection import train_test_split
#       4 from sklearn.preprocessing import LabelEncoder
#       5 import torch
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Read data

# %%
data = pd.read_csv('/home/aalab/Desktop/tripoFT/metadata.csv')

# %%
print("The first few rows of the DataFrame:")
print(data.head())

print("\nData info:")
print(data.info())

print("\nData columns:")
print(data.columns)

print("\nData described:")
print(data.describe())
# Out:
# The first few rows of the DataFrame:
#                                  filename      size  \
# 0  cadbury_dairy_milk_chocolate_piece.glb    152796
# 1          bonnie_melted_chocolate_ar.glb   8285860
# 2              chocobar_ice_cream (1).glb   4499300
# 3                           ice_cream.glb  12444648
# 4                   chocolate_truffle.glb   2084100
#
#                                          object_path
# 0  /home/aalab/Desktop/tripoFT/Dataset/cadbury_da...
# 1  /home/aalab/Desktop/tripoFT/Dataset/bonnie_mel...
# 2  /home/aalab/Desktop/tripoFT/Dataset/chocobar_i...
# 3  /home/aalab/Desktop/tripoFT/Dataset/ice_cream.glb
# 4  /home/aalab/Desktop/tripoFT/Dataset/chocolate_...
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   filename     145 non-null    object
#  1   size         145 non-null    int64
#  2   object_path  145 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.5+ KB
# None
#
# Data columns:
# Index(['filename', 'size', 'object_path'], dtype='object')
#
# Data described:
#                size
# count  1.450000e+02
# mean   1.302109e+07
# std    2.178698e+07
# min    1.987600e+04
# 25%    1.708740e+06
# 50%    5.081284e+06
# 75%    1.750160e+07
# max    1.431980e+08

# %% [markdown]
# Clean Data

# %%
data.drop_duplicates(inplace=True)

# Drop rows with missing values in specific columns
columns_with_missing_values = ['filename', 'size', 'object_path']
data.dropna(subset=columns_with_missing_values, inplace=True)

# Convert columns to appropriate data types
data['filename'] = data['filename'].astype(str)
data['size'] = data['size'].astype(str)
data['object_path'] = data['object_path'].astype(str)

# Print cleaned DataFrame
print(data)
# Out:
#                                    filename      size  \
# 0    cadbury_dairy_milk_chocolate_piece.glb    152796
# 1            bonnie_melted_chocolate_ar.glb   8285860
# 2                chocobar_ice_cream (1).glb   4499300
# 3                             ice_cream.glb  12444648
# 4                     chocolate_truffle.glb   2084100
# ..                                      ...       ...
# 140                     strawberry_cake.glb  25159596
# 141                jiggly_bunny_pudding.glb   1026416
# 142            kitchen_sink_fiesta_5149.glb  26103980
# 143   easter_egg_2024_marbled_chocolate.glb   3743544
# 144              paleta_payaso_lollypop.glb    439920
#
#                                            object_path
# 0    /home/aalab/Desktop/tripoFT/Dataset/cadbury_da...
# 1    /home/aalab/Desktop/tripoFT/Dataset/bonnie_mel...
# 2    /home/aalab/Desktop/tripoFT/Dataset/chocobar_i...
# 3    /home/aalab/Desktop/tripoFT/Dataset/ice_cream.glb
# 4    /home/aalab/Desktop/tripoFT/Dataset/chocolate_...
# ..                                                 ...
# 140  /home/aalab/Desktop/tripoFT/Dataset/strawberry...
# 141  /home/aalab/Desktop/tripoFT/Dataset/jiggly_bun...
# 142  /home/aalab/Desktop/tripoFT/Dataset/kitchen_si...
# 143  /home/aalab/Desktop/tripoFT/Dataset/easter_egg...
# 144  /home/aalab/Desktop/tripoFT/Dataset/paleta_pay...
#
# [145 rows x 3 columns]

# %% [markdown]
# Convert 3D Objects into a Usable Format that our model can work with, such as voxel grids. (This is in shape vertex and faces)

# %%
import os
import numpy as np
import trimesh

def voxelize_mesh(vertices, faces, grid_size=32):
    """Convert mesh to voxel grid."""
    # Create an empty voxel grid
    voxel_grid = np.zeros((grid_size, grid_size, grid_size), dtype=np.float32)

    # Normalize the vertices to fit in the grid
    vertices -= vertices.min(axis=0)
    vertices /= vertices.max(axis=0)
    vertices *= (grid_size - 1)

    # Rasterize the faces into the voxel grid
    for face in faces:
        verts = vertices[face].astype(int)
        x, y, z = zip(*verts)
        voxel_grid[x, y, z] = 1.0  # Mark the presence of vertices in the grid

    return voxel_grid

def convert_glb_to_tensors(input_folder, output_folder, grid_size=32):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop over all .glb files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.glb'):
            # Load the .glb file using trimesh
            file_path = os.path.join(input_folder, file_name)
            mesh = trimesh.load(file_path, force='mesh')

            # Extract vertices and faces
            vertices = mesh.vertices
            faces = mesh.faces

            # Convert mesh to voxel grid
            voxel_grid = voxelize_mesh(vertices, faces, grid_size=grid_size)

            # Add batch and channel dimensions
            voxel_grid = voxel_grid[np.newaxis, np.newaxis, :, :, :]

            # Save the tensor to a .npz file
            tensor_file_name = file_name.replace('.glb', '.npz')
            tensor_file_path = os.path.join(output_folder, tensor_file_name)
            np.savez(tensor_file_path, voxel_grid=voxel_grid)

            print(f'Successfully processed and saved: {tensor_file_name}')

input_folder = '/home/aalab/Desktop/tripoFT/Dataset'
output_folder = '/home/aalab/Desktop/tripoFT/tensors'
convert_glb_to_tensors(input_folder, output_folder)
# Out:
# Successfully processed and saved: cadbury_dairy_milk_chocolate_piece.npz
# Successfully processed and saved: bonnie_melted_chocolate_ar.npz
# Successfully processed and saved: chocobar_ice_cream (1).npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 54
#      52 input_folder = '/home/aalab/Desktop/tripoFT/Dataset'
#      53 output_folder = '/home/aalab/Desktop/tripoFT/tensors'
# ---> 54 convert_glb_to_tensors(input_folder, output_folder)
#
# Cell In[8], line 40, in convert_glb_to_tensors(input_folder, output_folder, grid_size)
#      37 faces = mesh.faces
#      39 # Convert mesh to voxel grid
# ---> 40 voxel_grid = voxelize_mesh(vertices, faces, grid_size=grid_size)
#      42 # Add batch and channel dimensions
#      43 voxel_grid = voxel_grid[np.newaxis, np.newaxis, :, :, :]
#
# Cell In[8], line 18, in voxelize_mesh(vertices, faces, grid_size)
#      16 for face in faces:
#      17     verts = vertices[face].astype(int)
# ---> 18     x, y, z = zip(*verts)
#      19     voxel_grid[x, y, z] = 1.0  # Mark the presence of vertices in the grid
#      21 return voxel_grid
#
# File ~/Desktop/tripoFT/TripoSR/venv_name/lib/python3.10/site-packages/trimesh/caching.py:180, in TrackedArray.__array_finalize__(self, obj)
#     160 class TrackedArray(np.ndarray):
#     161     """
#     162     Subclass of numpy.ndarray that provides hash methods
#     163     to track changes.
#    (...)
#     177         `xxh3_64, xxh_64, blake2b, sha256`
#     178     """
# --> 180     def __array_finalize__(self, obj):
#     181         """
#     182         Sets a modified flag on every TrackedArray
#     183         This flag will be set on every change as well as
#     184         during copies and certain types of slicing.
#     185         """
#     187         self._dirty_hash = True
#
# KeyboardInterrupt:

# %% [markdown]
# converting to tensor with shape (Batch size, Channel, Depth, Height, Width)

# %%
import os
import numpy as np
import trimesh

def voxelize_mesh(mesh, resolution=32):
    """
    Convert a mesh to a voxel grid of the specified resolution.
    """
    # Compute the voxel size
    voxel_size = (mesh.bounds[1] - mesh.bounds[0]).max() / resolution
    # Voxelize the mesh
    voxelized = mesh.voxelized(voxel_size)
    # Convert the voxelized mesh to a dense voxel grid
    filled = voxelized.matrix
    return filled

def convert_glb_to_tensors(input_folder, output_folder, resolution=32):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop over all .glb files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.glb'):
            # Load the .glb file using trimesh
            file_path = os.path.join(input_folder, file_name)
            mesh = trimesh.load(file_path, force='mesh')

            # Voxelize the mesh
            voxel_grid = voxelize_mesh(mesh, resolution)

            # Normalize the voxel grid to match [channels, depth, height, width]
            voxel_grid = voxel_grid[np.newaxis, :, :, :]  # Add channel dimension
            # No need to add an additional batch dimension

            # Save the tensor to a .npz file
            tensor_file_name = file_name.replace('.glb', '.npz')
            tensor_file_path = os.path.join(output_folder, tensor_file_name)
            np.savez(tensor_file_path, voxel_grid=voxel_grid)

            print(f'Successfully processed and saved: {tensor_file_name}')

input_folder = '/home/aalab/Desktop/tripoFT/Dataset'
output_folder = '/home/aalab/Desktop/tripoFT/tensors'
convert_glb_to_tensors(input_folder, output_folder, resolution=32)
# Out:
# Successfully processed and saved: cadbury_dairy_milk_chocolate_piece.npz
# Successfully processed and saved: bonnie_melted_chocolate_ar.npz
# Successfully processed and saved: chocobar_ice_cream (1).npz
# Successfully processed and saved: ice_cream.npz
# Successfully processed and saved: chocolate_truffle.npz
# Successfully processed and saved: oreo.npz
# Successfully processed and saved: heart_cake.npz
# Successfully processed and saved: candy_vending_machine.npz
# Successfully processed and saved: gummy_bear_bull.npz
# Successfully processed and saved: valentines_heart.npz
# Successfully processed and saved: beardpapas_smores_puff__scan.npz
# Successfully processed and saved: doughnut_pack.npz
# Successfully processed and saved: cc0_-_candies.npz
# Successfully processed and saved: biscuit.npz
# Successfully processed and saved: hot_fudge_warmer.npz
# Successfully processed and saved: chocolate_milkshake.npz
# Successfully processed and saved: vegan_icecream.npz
# Successfully processed and saved: power_shake_chocolate.npz
# Successfully processed and saved: adidas_chocolate_to_my_strawberry_sneaker.npz
# Successfully processed and saved: ferrero_rocher.npz
# Successfully processed and saved: ice_cream_sandwich.npz
# Successfully processed and saved: blue_mm_without_eyes (1).npz
# Successfully processed and saved: worlds_last_choco_taco.npz
# Successfully processed and saved: chocolate_python.npz
# Successfully processed and saved: krispy_kreme_twix_bar_doughnut.npz
# Successfully processed and saved: christmas_cookie_.rawscan..npz
# Successfully processed and saved: lindt_gold_easter_bunny.npz
# Successfully processed and saved: fluid_simulation.npz
# Successfully processed and saved: ice-cream.npz
# Successfully processed and saved: candy_tractor.npz
# Successfully processed and saved: free_to_download_handpainted_stylized_cupcake.npz
# Successfully processed and saved: paper_cup_perfect.npz
# Successfully processed and saved: chocolate_muffin.npz
# Successfully processed and saved: chocolate_waffles.npz
# Successfully processed and saved: banana_yellow_low_poly_asset.npz
# Successfully processed and saved: chocolate_cake (1).npz
# Successfully processed and saved: walshbear.npz
# Successfully processed and saved: chocolate_dessert.npz
# Successfully processed and saved: s00002_brownie_2.npz
# Successfully processed and saved: the_simpsons_game_2007_-_chocolate_bunny.npz
# Successfully processed and saved: cup_cake.npz
# Successfully processed and saved: strawberry_cake_low_poly.npz
# Successfully processed and saved: chocolates_etagere_-_decoration.npz
# Successfully processed and saved: sundae_-_sketchfab_low_poly_challenge_desserts.npz
# Successfully processed and saved: cookies_3dst6.npz
# Successfully processed and saved: sugar_bunny_in_choco.npz
# Successfully processed and saved: kinder_surprise_egg.npz
# Successfully processed and saved: gummy_bear (1).npz
# Successfully processed and saved: chocolate_berry_cake.npz
# Successfully processed and saved: hugs_kisses__cookies.npz
# Successfully processed and saved: cupcake.npz
# Successfully processed and saved: chocolate_donut_3d_scan_free.npz
# Successfully processed and saved: saint_nicholas_boot.npz
# Successfully processed and saved: hershey_chocolate_syrup.npz
# Successfully processed and saved: italian_chocolates.npz
# Successfully processed and saved: florentiner.npz
# Successfully processed and saved: hazelnut_twist.npz
# Successfully processed and saved: chocolate_mini_cookies.npz
# Successfully processed and saved: cutie_cupcake.npz
# Successfully processed and saved: happy_easter_chocolate_bunny.npz
# Successfully processed and saved: chocolate_starbucks_muffin.npz
# Successfully processed and saved: harry_potter_official_chocolate_frog_box.npz
# Successfully processed and saved: sliced_marble_cake.npz
# Successfully processed and saved: jelly.npz
# Successfully processed and saved: chocolate.npz
# Successfully processed and saved: break_3december_day_19.npz
# Successfully processed and saved: mobile_-_gummy_bear_runner_-_santa_hat.npz
# Successfully processed and saved: melting_heart.npz
# Successfully processed and saved: pink_donut_with_sprinkles.npz
# Successfully processed and saved: gummy_bear_gummibar_model.npz
# Successfully processed and saved: gummy_bear (2).npz
# Successfully processed and saved: mug-o-otterlatte.npz
# Successfully processed and saved: disco_gummy_bear.npz
# Successfully processed and saved: dreamy_chocolate_surprise.npz
# Successfully processed and saved: chocolate_mousse_cake.npz
# Successfully processed and saved: simple_chocolate_bar.npz
# Successfully processed and saved: chocolate_bars.npz
# Successfully processed and saved: schokokuchen_lina_2024.npz
# Successfully processed and saved: chocolates.npz
# Successfully processed and saved: low-poly_chocolate_bar.npz
# Successfully processed and saved: tim_tam.npz
# Successfully processed and saved: nestle_crunch_bar.npz
# Successfully processed and saved: chocolate_cake.npz
# Successfully processed and saved: lava_cake.npz
# Successfully processed and saved: a_little_bite_of_france..npz
# Successfully processed and saved: sofa.npz
# Successfully processed and saved: 18th_century_chocolate_bar.npz
# Successfully processed and saved: chocolate_frog.npz
# Successfully processed and saved: dark_chocolate_syrup.npz
# Successfully processed and saved: milkshake_my_friend.npz
# Successfully processed and saved: long_donut.npz
# Successfully processed and saved: hazelnuts_chocolate_bar.npz
# Successfully processed and saved: chocobar_ice_cream.npz
# Successfully processed and saved: blue_mm_without_eyes.npz
# Successfully processed and saved: ketchup.npz
# Successfully processed and saved: cannoli.npz
# Successfully processed and saved: hot_chocolate_with_whipped_cream.npz
# Successfully processed and saved: photorealistic_chocolate_milk_carton_pint.npz
# Successfully processed and saved: metamorphosis_chocolate_-_wavy.npz
# Successfully processed and saved: easter_bunny_cupcake.npz
# Successfully processed and saved: coffee_crisp.npz
# Successfully processed and saved: birthday_cake.npz
# Successfully processed and saved: chocolate_cupcake.npz
# Successfully processed and saved: chocolate_easter_bunny.npz
# Successfully processed and saved: brownie_square.npz
# Successfully processed and saved: cake_gradient.npz
# Successfully processed and saved: chocolate_cookies.npz
# Successfully processed and saved: kawai_ice-cream.npz
# Successfully processed and saved: chocolate_donut.npz
# Successfully processed and saved: white_chocolate_cake.npz
# Successfully processed and saved: ferrero_rocher__chocolate.npz
# Successfully processed and saved: chocolate_hedgehog.npz
# Successfully processed and saved: chocolate_easter_bunny (1).npz
# Successfully processed and saved: the_meadows_arctic_swirl_frozen_custard_dessert.npz
# Successfully processed and saved: chocolate_buttercream_cupcake.npz
# Successfully processed and saved: valentines_chocolate_heart.npz
# Successfully processed and saved: ice_cream (1).npz
# Successfully processed and saved: pancakes_low_poly_model.npz
# Successfully processed and saved: chocolate_muffin_game_ready__2k_pbr.npz
# Successfully processed and saved: nesquik_chocolate_milk.npz
# Successfully processed and saved: paleta_payaso.npz
# Successfully processed and saved: lindt_gold_chocolate_bunny.npz
# Successfully processed and saved: donut.npz
# Successfully processed and saved: low_poly_chocolate_bar.npz
# Successfully processed and saved: pastry_bear.npz
# Successfully processed and saved: candy_crush_bomba_de_color.npz
# Successfully processed and saved: gummy_bears.npz
# Successfully processed and saved: chocolate_cocktail.npz
# Successfully processed and saved: cake.npz
# Successfully processed and saved: chocolate_boy.npz
# Successfully processed and saved: chocolate_muffin_school_project.npz
# Successfully processed and saved: nutella_jar_of_chocolate.npz
# Successfully processed and saved: chocolate_pie.npz
# Successfully processed and saved: 3december_choco_cake.npz
# Successfully processed and saved: ice_cream_in_marble_bowl.npz
# Successfully processed and saved: gummy_bear.npz
# Successfully processed and saved: chocolate_teddy_bear.npz
# Successfully processed and saved: lcm_rice_crispy_treat.npz
# Successfully processed and saved: hershey_kiss.npz
# Successfully processed and saved: hot_chocolate.npz
# Successfully processed and saved: strawberry_cake.npz
# Successfully processed and saved: jiggly_bunny_pudding.npz
# Successfully processed and saved: kitchen_sink_fiesta_5149.npz
# Successfully processed and saved: easter_egg_2024_marbled_chocolate.npz
# Successfully processed and saved: paleta_payaso_lollypop.npz

# %%
import numpy as np
import os

def check_npz_shapes(folder_path):
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.npz'):
            file_path = os.path.join(folder_path, file_name)
            data = np.load(file_path)
            voxel_grid = data['voxel_grid']
            print(f'{file_name}: {voxel_grid.shape}')

folder_path = '/home/aalab/Desktop/tripoFT/tensors'
check_npz_shapes(folder_path)
# Out:
# cup_cake.npz: (1, 25, 33, 25)
# brownie_square.npz: (1, 33, 15, 33)
# ice_cream (1).npz: (1, 5, 33, 13)
# schokokuchen_lina_2024.npz: (1, 32, 15, 33)
# hot_chocolate_with_whipped_cream.npz: (1, 15, 33, 15)
# doughnut_pack.npz: (1, 33, 8, 33)
# simple_chocolate_bar.npz: (1, 33, 2, 15)
# hershey_kiss.npz: (1, 29, 33, 21)
# chocobar_ice_cream.npz: (1, 33, 8, 27)
# strawberry_cake_low_poly.npz: (1, 31, 16, 33)
# paper_cup_perfect.npz: (1, 25, 33, 25)
# chocolate_buttercream_cupcake.npz: (1, 33, 25, 32)
# krispy_kreme_twix_bar_doughnut.npz: (1, 17, 12, 33)
# bonnie_melted_chocolate_ar.npz: (1, 33, 33, 9)
# chocolate_cake.npz: (1, 15, 21, 33)
# lindt_gold_chocolate_bunny.npz: (1, 19, 33, 27)
# the_meadows_arctic_swirl_frozen_custard_dessert.npz: (1, 33, 19, 33)
# paleta_payaso.npz: (1, 14, 33, 9)
# blue_mm_without_eyes.npz: (1, 33, 24, 11)
# fluid_simulation.npz: (1, 33, 17, 33)
# cc0_-_candies.npz: (1, 26, 7, 33)
# pancakes_low_poly_model.npz: (1, 33, 19, 33)
# long_donut.npz: (1, 17, 10, 33)
# easter_egg_2024_marbled_chocolate.npz: (1, 17, 33, 17)
# hot_fudge_warmer.npz: (1, 21, 33, 18)
# kawai_ice-cream.npz: (1, 15, 33, 12)
# chocolate_berry_cake.npz: (1, 33, 30, 33)
# nutella_jar_of_chocolate.npz: (1, 26, 33, 24)
# kinder_surprise_egg.npz: (1, 23, 33, 25)
# lindt_gold_easter_bunny.npz: (1, 25, 33, 16)
# ferrero_rocher__chocolate.npz: (1, 32, 17, 33)
# gummy_bear (2).npz: (1, 29, 33, 19)
# heart_cake.npz: (1, 31, 25, 33)
# jelly.npz: (1, 33, 17, 33)
# jiggly_bunny_pudding.npz: (1, 33, 19, 33)
# milkshake_my_friend.npz: (1, 15, 33, 15)
# chocolate_pie.npz: (1, 23, 18, 33)
# sugar_bunny_in_choco.npz: (1, 33, 15, 21)
# ice_cream_sandwich.npz: (1, 33, 15, 33)
# chocolate_cake (1).npz: (1, 33, 27, 33)
# chocolate_easter_bunny.npz: (1, 13, 33, 19)
# chocolate_milkshake.npz: (1, 30, 33, 17)
# oreo.npz: (1, 33, 5, 33)
# chocolate_cocktail.npz: (1, 33, 22, 33)
# chocolate_donut.npz: (1, 31, 19, 33)
# hazelnut_twist.npz: (1, 33, 10, 30)
# chocolate_teddy_bear.npz: (1, 22, 33, 27)
# ice_cream.npz: (1, 22, 33, 11)
# gummy_bear (1).npz: (1, 23, 33, 28)
# chocolate_dessert.npz: (1, 31, 25, 33)
# chocolate_python.npz: (1, 6, 20, 33)
# strawberry_cake.npz: (1, 33, 13, 32)
# break_3december_day_19.npz: (1, 33, 33, 23)
# gummy_bears.npz: (1, 10, 20, 33)
# cadbury_dairy_milk_chocolate_piece.npz: (1, 33, 11, 33)
# christmas_cookie_.rawscan..npz: (1, 32, 33, 9)
# chocolate_waffles.npz: (1, 16, 4, 33)
# cutie_cupcake.npz: (1, 21, 33, 21)
# chocobar_ice_cream (1).npz: (1, 33, 8, 27)
# chocolates_etagere_-_decoration.npz: (1, 33, 33, 23)
# chocolate_cookies.npz: (1, 33, 10, 32)
# hazelnuts_chocolate_bar.npz: (1, 33, 5, 31)
# ferrero_rocher.npz: (1, 33, 27, 33)
# coffee_crisp.npz: (1, 33, 10, 12)
# nestle_crunch_bar.npz: (1, 33, 19, 2)
# saint_nicholas_boot.npz: (1, 33, 24, 26)
# cupcake.npz: (1, 29, 33, 27)
# worlds_last_choco_taco.npz: (1, 31, 9, 33)
# chocolate_easter_bunny (1).npz: (1, 22, 33, 17)
# chocolate_frog.npz: (1, 29, 33, 33)
# candy_crush_bomba_de_color.npz: (1, 32, 33, 33)
# s00002_brownie_2.npz: (1, 33, 15, 27)
# ice_cream_in_marble_bowl.npz: (1, 27, 33, 27)
# low-poly_chocolate_bar.npz: (1, 17, 2, 33)
# pink_donut_with_sprinkles.npz: (1, 33, 14, 33)
# the_simpsons_game_2007_-_chocolate_bunny.npz: (1, 11, 33, 20)
# hugs_kisses__cookies.npz: (1, 30, 25, 33)
# power_shake_chocolate.npz: (1, 13, 33, 14)
# chocolate_starbucks_muffin.npz: (1, 33, 31, 33)
# chocolate_muffin_game_ready__2k_pbr.npz: (1, 32, 30, 33)
# tim_tam.npz: (1, 33, 8, 14)
# hot_chocolate.npz: (1, 24, 33, 18)
# donut.npz: (1, 33, 11, 33)
# ketchup.npz: (1, 29, 33, 31)
# mug-o-otterlatte.npz: (1, 33, 23, 21)
# chocolate_bars.npz: (1, 30, 8, 33)
# 18th_century_chocolate_bar.npz: (1, 33, 6, 33)
# florentiner.npz: (1, 29, 33, 9)
# chocolate_muffin_school_project.npz: (1, 33, 25, 33)
# chocolates.npz: (1, 33, 17, 31)
# gummy_bear_gummibar_model.npz: (1, 33, 32, 16)
# lcm_rice_crispy_treat.npz: (1, 9, 33, 19)
# chocolate.npz: (1, 31, 1, 33)
# sundae_-_sketchfab_low_poly_challenge_desserts.npz: (1, 15, 33, 15)
# dreamy_chocolate_surprise.npz: (1, 14, 19, 33)
# chocolate_mousse_cake.npz: (1, 31, 29, 33)
# sofa.npz: (1, 33, 11, 14)
# cake.npz: (1, 21, 33, 21)
# mobile_-_gummy_bear_runner_-_santa_hat.npz: (1, 31, 30, 33)
# ice-cream.npz: (1, 16, 33, 17)
# metamorphosis_chocolate_-_wavy.npz: (1, 32, 17, 33)
# chocolate_donut_3d_scan_free.npz: (1, 32, 13, 33)
# valentines_chocolate_heart.npz: (1, 33, 30, 17)
# valentines_heart.npz: (1, 27, 33, 21)
# paleta_payaso_lollypop.npz: (1, 13, 33, 5)
# hershey_chocolate_syrup.npz: (1, 17, 33, 9)
# biscuit.npz: (1, 19, 13, 33)
# white_chocolate_cake.npz: (1, 32, 10, 33)
# harry_potter_official_chocolate_frog_box.npz: (1, 33, 31, 22)
# chocolate_boy.npz: (1, 9, 29, 33)
# melting_heart.npz: (1, 13, 33, 19)
# chocolate_hedgehog.npz: (1, 33, 31, 25)
# lava_cake.npz: (1, 32, 11, 33)
# chocolate_truffle.npz: (1, 33, 29, 33)
# a_little_bite_of_france..npz: (1, 33, 18, 32)
# blue_mm_without_eyes (1).npz: (1, 33, 24, 11)
# beardpapas_smores_puff__scan.npz: (1, 33, 28, 32)
# 3december_choco_cake.npz: (1, 19, 33, 19)
# chocolate_cupcake.npz: (1, 23, 33, 23)
# italian_chocolates.npz: (1, 33, 28, 33)
# low_poly_chocolate_bar.npz: (1, 33, 3, 19)
# walshbear.npz: (1, 27, 33, 21)
# dark_chocolate_syrup.npz: (1, 7, 33, 25)
# kitchen_sink_fiesta_5149.npz: (1, 29, 33, 31)
# candy_vending_machine.npz: (1, 9, 33, 9)
# chocolate_muffin.npz: (1, 32, 30, 33)
# easter_bunny_cupcake.npz: (1, 25, 33, 21)
# birthday_cake.npz: (1, 33, 18, 33)
# pastry_bear.npz: (1, 27, 33, 22)
# photorealistic_chocolate_milk_carton_pint.npz: (1, 19, 33, 20)
# adidas_chocolate_to_my_strawberry_sneaker.npz: (1, 13, 14, 33)
# vegan_icecream.npz: (1, 24, 15, 33)
# chocolate_mini_cookies.npz: (1, 33, 16, 8)
# gummy_bear_bull.npz: (1, 20, 24, 33)
# cookies_3dst6.npz: (1, 33, 13, 33)
# cake_gradient.npz: (1, 33, 19, 33)
# gummy_bear.npz: (1, 17, 33, 16)
# cannoli.npz: (1, 33, 20, 21)
# banana_yellow_low_poly_asset.npz: (1, 33, 23, 29)
# disco_gummy_bear.npz: (1, 18, 33, 17)
# happy_easter_chocolate_bunny.npz: (1, 9, 33, 14)
# nesquik_chocolate_milk.npz: (1, 9, 33, 11)
# free_to_download_handpainted_stylized_cupcake.npz: (1, 23, 33, 23)
# sliced_marble_cake.npz: (1, 24, 15, 33)
# candy_tractor.npz: (1, 33, 23, 26)

# %% [markdown]
# Data Augmentation

# %%
import os
import numpy as np

def rotate_voxel_grid(voxel_grid, axis, angle):
    """
    Rotate the voxel grid along a specified axis by the given angle (in degrees).
    """
    from scipy.ndimage import rotate
    rotated = rotate(voxel_grid, angle, axes=axis, reshape=False, mode='nearest')
    return rotated

def flip_voxel_grid(voxel_grid, axis):
    """
    Flip the voxel grid along a specified axis.
    """
    flipped = np.flip(voxel_grid, axis=axis)
    return flipped

def add_noise_to_voxel_grid(voxel_grid, noise_level=0.01):
    """
    Add Gaussian noise to the voxel grid.
    """
    noise = np.random.normal(0, noise_level, voxel_grid.shape)
    noisy_voxel_grid = voxel_grid + noise
    return np.clip(noisy_voxel_grid, 0, 1)  # Ensure the values are within [0, 1]

def augment_voxel_grid(voxel_grid):
    """
    Apply various augmentations to the voxel grid and return a list of augmented grids.
    """
    augmentations = []

    # Original grid
    augmentations.append(voxel_grid)

    # Rotations
    for axis in [(1, 2), (1, 3), (2, 3)]:
        for angle in [90, 180, 270]:
            augmentations.append(rotate_voxel_grid(voxel_grid, axis, angle))

    # Flips
    for axis in [1, 2, 3]:
        augmentations.append(flip_voxel_grid(voxel_grid, axis))

    # Adding noise
    augmentations.append(add_noise_to_voxel_grid(voxel_grid, noise_level=0.01))

    return augmentations

def augment_tensor_files(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop over all .npz files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.npz'):
            # Load the .npz file
            file_path = os.path.join(input_folder, file_name)
            data = np.load(file_path)
            voxel_grid = data['voxel_grid']

            # Apply augmentations
            augmented_voxel_grids = augment_voxel_grid(voxel_grid)

            # Save augmented voxel grids to new .npz files
            base_name = file_name.replace('.npz', '')
            for i, aug_voxel_grid in enumerate(augmented_voxel_grids):
                aug_file_name = f'{base_name}_aug_{i}.npz'
                aug_file_path = os.path.join(output_folder, aug_file_name)
                np.savez(aug_file_path, voxel_grid=aug_voxel_grid)

                print(f'Successfully augmented and saved: {aug_file_name}')

# Example usage
input_folder = '/home/aalab/Desktop/tripoFT/tensors'
output_folder = '/home/aalab/Desktop/tripoFT/augmented_tensors'
augment_tensor_files(input_folder, output_folder)
# Out:
# Successfully augmented and saved: cup_cake_aug_0.npz
# Successfully augmented and saved: cup_cake_aug_1.npz
# Successfully augmented and saved: cup_cake_aug_2.npz
# Successfully augmented and saved: cup_cake_aug_3.npz
# Successfully augmented and saved: cup_cake_aug_4.npz
# Successfully augmented and saved: cup_cake_aug_5.npz
# Successfully augmented and saved: cup_cake_aug_6.npz
# Successfully augmented and saved: cup_cake_aug_7.npz
# Successfully augmented and saved: cup_cake_aug_8.npz
# Successfully augmented and saved: cup_cake_aug_9.npz
# Successfully augmented and saved: cup_cake_aug_10.npz
# Successfully augmented and saved: cup_cake_aug_11.npz
# Successfully augmented and saved: cup_cake_aug_12.npz
# Successfully augmented and saved: cup_cake_aug_13.npz
# Successfully augmented and saved: brownie_square_aug_0.npz
# Successfully augmented and saved: brownie_square_aug_1.npz
# Successfully augmented and saved: brownie_square_aug_2.npz
# Successfully augmented and saved: brownie_square_aug_3.npz
# Successfully augmented and saved: brownie_square_aug_4.npz
# Successfully augmented and saved: brownie_square_aug_5.npz
# Successfully augmented and saved: brownie_square_aug_6.npz
# Successfully augmented and saved: brownie_square_aug_7.npz
# Successfully augmented and saved: brownie_square_aug_8.npz
# Successfully augmented and saved: brownie_square_aug_9.npz
# Successfully augmented and saved: brownie_square_aug_10.npz
# Successfully augmented and saved: brownie_square_aug_11.npz
# Successfully augmented and saved: brownie_square_aug_12.npz
# Successfully augmented and saved: brownie_square_aug_13.npz
# Successfully augmented and saved: ice_cream (1)_aug_0.npz
# Successfully augmented and saved: ice_cream (1)_aug_1.npz
# Successfully augmented and saved: ice_cream (1)_aug_2.npz
# Successfully augmented and saved: ice_cream (1)_aug_3.npz
# Successfully augmented and saved: ice_cream (1)_aug_4.npz
# Successfully augmented and saved: ice_cream (1)_aug_5.npz
# Successfully augmented and saved: ice_cream (1)_aug_6.npz
# Successfully augmented and saved: ice_cream (1)_aug_7.npz
# Successfully augmented and saved: ice_cream (1)_aug_8.npz
# Successfully augmented and saved: ice_cream (1)_aug_9.npz
# Successfully augmented and saved: ice_cream (1)_aug_10.npz
# Successfully augmented and saved: ice_cream (1)_aug_11.npz
# Successfully augmented and saved: ice_cream (1)_aug_12.npz
# Successfully augmented and saved: ice_cream (1)_aug_13.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_0.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_1.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_2.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_3.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_4.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_5.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_6.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_7.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_8.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_9.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_10.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_11.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_12.npz
# Successfully augmented and saved: schokokuchen_lina_2024_aug_13.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_0.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_1.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_2.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_3.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_4.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_5.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_6.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_7.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_8.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_9.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_10.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_11.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_12.npz
# Successfully augmented and saved: hot_chocolate_with_whipped_cream_aug_13.npz
# Successfully augmented and saved: doughnut_pack_aug_0.npz
# Successfully augmented and saved: doughnut_pack_aug_1.npz
# Successfully augmented and saved: doughnut_pack_aug_2.npz
# Successfully augmented and saved: doughnut_pack_aug_3.npz
# Successfully augmented and saved: doughnut_pack_aug_4.npz
# Successfully augmented and saved: doughnut_pack_aug_5.npz
# Successfully augmented and saved: doughnut_pack_aug_6.npz
# Successfully augmented and saved: doughnut_pack_aug_7.npz
# Successfully augmented and saved: doughnut_pack_aug_8.npz
# Successfully augmented and saved: doughnut_pack_aug_9.npz
# Successfully augmented and saved: doughnut_pack_aug_10.npz
# Successfully augmented and saved: doughnut_pack_aug_11.npz
# Successfully augmented and saved: doughnut_pack_aug_12.npz
# Successfully augmented and saved: doughnut_pack_aug_13.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_0.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_1.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_2.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_3.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_4.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_5.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_6.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_7.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_8.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_9.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_10.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_11.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_12.npz
# Successfully augmented and saved: simple_chocolate_bar_aug_13.npz
# Successfully augmented and saved: hershey_kiss_aug_0.npz
# Successfully augmented and saved: hershey_kiss_aug_1.npz
# Successfully augmented and saved: hershey_kiss_aug_2.npz
# Successfully augmented and saved: hershey_kiss_aug_3.npz
# Successfully augmented and saved: hershey_kiss_aug_4.npz
# Successfully augmented and saved: hershey_kiss_aug_5.npz
# Successfully augmented and saved: hershey_kiss_aug_6.npz
# Successfully augmented and saved: hershey_kiss_aug_7.npz
# Successfully augmented and saved: hershey_kiss_aug_8.npz
# Successfully augmented and saved: hershey_kiss_aug_9.npz
# Successfully augmented and saved: hershey_kiss_aug_10.npz
# Successfully augmented and saved: hershey_kiss_aug_11.npz
# Successfully augmented and saved: hershey_kiss_aug_12.npz
# Successfully augmented and saved: hershey_kiss_aug_13.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_0.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_1.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_2.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_3.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_4.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_5.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_6.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_7.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_8.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_9.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_10.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_11.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_12.npz
# Successfully augmented and saved: chocobar_ice_cream_aug_13.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_0.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_1.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_2.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_3.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_4.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_5.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_6.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_7.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_8.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_9.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_10.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_11.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_12.npz
# Successfully augmented and saved: strawberry_cake_low_poly_aug_13.npz
# Successfully augmented and saved: paper_cup_perfect_aug_0.npz
# Successfully augmented and saved: paper_cup_perfect_aug_1.npz
# Successfully augmented and saved: paper_cup_perfect_aug_2.npz
# Successfully augmented and saved: paper_cup_perfect_aug_3.npz
# Successfully augmented and saved: paper_cup_perfect_aug_4.npz
# Successfully augmented and saved: paper_cup_perfect_aug_5.npz
# Successfully augmented and saved: paper_cup_perfect_aug_6.npz
# Successfully augmented and saved: paper_cup_perfect_aug_7.npz
# Successfully augmented and saved: paper_cup_perfect_aug_8.npz
# Successfully augmented and saved: paper_cup_perfect_aug_9.npz
# Successfully augmented and saved: paper_cup_perfect_aug_10.npz
# Successfully augmented and saved: paper_cup_perfect_aug_11.npz
# Successfully augmented and saved: paper_cup_perfect_aug_12.npz
# Successfully augmented and saved: paper_cup_perfect_aug_13.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_0.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_1.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_2.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_3.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_4.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_5.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_6.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_7.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_8.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_9.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_10.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_11.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_12.npz
# Successfully augmented and saved: chocolate_buttercream_cupcake_aug_13.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_0.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_1.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_2.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_3.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_4.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_5.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_6.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_7.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_8.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_9.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_10.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_11.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_12.npz
# Successfully augmented and saved: krispy_kreme_twix_bar_doughnut_aug_13.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_0.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_1.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_2.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_3.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_4.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_5.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_6.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_7.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_8.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_9.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_10.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_11.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_12.npz
# Successfully augmented and saved: bonnie_melted_chocolate_ar_aug_13.npz
# Successfully augmented and saved: chocolate_cake_aug_0.npz
# Successfully augmented and saved: chocolate_cake_aug_1.npz
# Successfully augmented and saved: chocolate_cake_aug_2.npz
# Successfully augmented and saved: chocolate_cake_aug_3.npz
# Successfully augmented and saved: chocolate_cake_aug_4.npz
# Successfully augmented and saved: chocolate_cake_aug_5.npz
# Successfully augmented and saved: chocolate_cake_aug_6.npz
# Successfully augmented and saved: chocolate_cake_aug_7.npz
# Successfully augmented and saved: chocolate_cake_aug_8.npz
# Successfully augmented and saved: chocolate_cake_aug_9.npz
# Successfully augmented and saved: chocolate_cake_aug_10.npz
# Successfully augmented and saved: chocolate_cake_aug_11.npz
# Successfully augmented and saved: chocolate_cake_aug_12.npz
# Successfully augmented and saved: chocolate_cake_aug_13.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_0.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_1.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_2.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_3.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_4.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_5.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_6.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_7.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_8.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_9.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_10.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_11.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_12.npz
# Successfully augmented and saved: lindt_gold_chocolate_bunny_aug_13.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_0.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_1.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_2.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_3.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_4.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_5.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_6.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_7.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_8.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_9.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_10.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_11.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_12.npz
# Successfully augmented and saved: the_meadows_arctic_swirl_frozen_custard_dessert_aug_13.npz
# Successfully augmented and saved: paleta_payaso_aug_0.npz
# Successfully augmented and saved: paleta_payaso_aug_1.npz
# Successfully augmented and saved: paleta_payaso_aug_2.npz
# Successfully augmented and saved: paleta_payaso_aug_3.npz
# Successfully augmented and saved: paleta_payaso_aug_4.npz
# Successfully augmented and saved: paleta_payaso_aug_5.npz
# Successfully augmented and saved: paleta_payaso_aug_6.npz
# Successfully augmented and saved: paleta_payaso_aug_7.npz
# Successfully augmented and saved: paleta_payaso_aug_8.npz
# Successfully augmented and saved: paleta_payaso_aug_9.npz
# Successfully augmented and saved: paleta_payaso_aug_10.npz
# Successfully augmented and saved: paleta_payaso_aug_11.npz
# Successfully augmented and saved: paleta_payaso_aug_12.npz
# Successfully augmented and saved: paleta_payaso_aug_13.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_0.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_1.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_2.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_3.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_4.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_5.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_6.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_7.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_8.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_9.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_10.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_11.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_12.npz
# Successfully augmented and saved: blue_mm_without_eyes_aug_13.npz
# Successfully augmented and saved: fluid_simulation_aug_0.npz
# Successfully augmented and saved: fluid_simulation_aug_1.npz
# Successfully augmented and saved: fluid_simulation_aug_2.npz
# Successfully augmented and saved: fluid_simulation_aug_3.npz
# Successfully augmented and saved: fluid_simulation_aug_4.npz
# Successfully augmented and saved: fluid_simulation_aug_5.npz
# Successfully augmented and saved: fluid_simulation_aug_6.npz
# Successfully augmented and saved: fluid_simulation_aug_7.npz
# Successfully augmented and saved: fluid_simulation_aug_8.npz
# Successfully augmented and saved: fluid_simulation_aug_9.npz
# Successfully augmented and saved: fluid_simulation_aug_10.npz
# Successfully augmented and saved: fluid_simulation_aug_11.npz
# Successfully augmented and saved: fluid_simulation_aug_12.npz
# Successfully augmented and saved: fluid_simulation_aug_13.npz
# Successfully augmented and saved: cc0_-_candies_aug_0.npz
# Successfully augmented and saved: cc0_-_candies_aug_1.npz
# Successfully augmented and saved: cc0_-_candies_aug_2.npz
# Successfully augmented and saved: cc0_-_candies_aug_3.npz
# Successfully augmented and saved: cc0_-_candies_aug_4.npz
# Successfully augmented and saved: cc0_-_candies_aug_5.npz
# Successfully augmented and saved: cc0_-_candies_aug_6.npz
# Successfully augmented and saved: cc0_-_candies_aug_7.npz
# Successfully augmented and saved: cc0_-_candies_aug_8.npz
# Successfully augmented and saved: cc0_-_candies_aug_9.npz
# Successfully augmented and saved: cc0_-_candies_aug_10.npz
# Successfully augmented and saved: cc0_-_candies_aug_11.npz
# Successfully augmented and saved: cc0_-_candies_aug_12.npz
# Successfully augmented and saved: cc0_-_candies_aug_13.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_0.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_1.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_2.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_3.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_4.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_5.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_6.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_7.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_8.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_9.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_10.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_11.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_12.npz
# Successfully augmented and saved: pancakes_low_poly_model_aug_13.npz
# Successfully augmented and saved: long_donut_aug_0.npz
# Successfully augmented and saved: long_donut_aug_1.npz
# Successfully augmented and saved: long_donut_aug_2.npz
# Successfully augmented and saved: long_donut_aug_3.npz
# Successfully augmented and saved: long_donut_aug_4.npz
# Successfully augmented and saved: long_donut_aug_5.npz
# Successfully augmented and saved: long_donut_aug_6.npz
# Successfully augmented and saved: long_donut_aug_7.npz
# Successfully augmented and saved: long_donut_aug_8.npz
# Successfully augmented and saved: long_donut_aug_9.npz
# Successfully augmented and saved: long_donut_aug_10.npz
# Successfully augmented and saved: long_donut_aug_11.npz
# Successfully augmented and saved: long_donut_aug_12.npz
# Successfully augmented and saved: long_donut_aug_13.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_0.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_1.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_2.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_3.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_4.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_5.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_6.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_7.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_8.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_9.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_10.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_11.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_12.npz
# Successfully augmented and saved: easter_egg_2024_marbled_chocolate_aug_13.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_0.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_1.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_2.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_3.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_4.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_5.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_6.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_7.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_8.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_9.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_10.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_11.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_12.npz
# Successfully augmented and saved: hot_fudge_warmer_aug_13.npz
# Successfully augmented and saved: kawai_ice-cream_aug_0.npz
# Successfully augmented and saved: kawai_ice-cream_aug_1.npz
# Successfully augmented and saved: kawai_ice-cream_aug_2.npz
# Successfully augmented and saved: kawai_ice-cream_aug_3.npz
# Successfully augmented and saved: kawai_ice-cream_aug_4.npz
# Successfully augmented and saved: kawai_ice-cream_aug_5.npz
# Successfully augmented and saved: kawai_ice-cream_aug_6.npz
# Successfully augmented and saved: kawai_ice-cream_aug_7.npz
# Successfully augmented and saved: kawai_ice-cream_aug_8.npz
# Successfully augmented and saved: kawai_ice-cream_aug_9.npz
# Successfully augmented and saved: kawai_ice-cream_aug_10.npz
# Successfully augmented and saved: kawai_ice-cream_aug_11.npz
# Successfully augmented and saved: kawai_ice-cream_aug_12.npz
# Successfully augmented and saved: kawai_ice-cream_aug_13.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_0.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_1.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_2.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_3.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_4.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_5.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_6.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_7.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_8.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_9.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_10.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_11.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_12.npz
# Successfully augmented and saved: chocolate_berry_cake_aug_13.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_0.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_1.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_2.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_3.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_4.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_5.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_6.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_7.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_8.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_9.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_10.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_11.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_12.npz
# Successfully augmented and saved: nutella_jar_of_chocolate_aug_13.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_0.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_1.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_2.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_3.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_4.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_5.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_6.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_7.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_8.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_9.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_10.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_11.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_12.npz
# Successfully augmented and saved: kinder_surprise_egg_aug_13.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_0.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_1.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_2.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_3.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_4.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_5.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_6.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_7.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_8.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_9.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_10.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_11.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_12.npz
# Successfully augmented and saved: lindt_gold_easter_bunny_aug_13.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_0.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_1.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_2.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_3.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_4.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_5.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_6.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_7.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_8.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_9.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_10.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_11.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_12.npz
# Successfully augmented and saved: ferrero_rocher__chocolate_aug_13.npz
# Successfully augmented and saved: gummy_bear (2)_aug_0.npz
# Successfully augmented and saved: gummy_bear (2)_aug_1.npz
# Successfully augmented and saved: gummy_bear (2)_aug_2.npz
# Successfully augmented and saved: gummy_bear (2)_aug_3.npz
# Successfully augmented and saved: gummy_bear (2)_aug_4.npz
# Successfully augmented and saved: gummy_bear (2)_aug_5.npz
# Successfully augmented and saved: gummy_bear (2)_aug_6.npz
# Successfully augmented and saved: gummy_bear (2)_aug_7.npz
# Successfully augmented and saved: gummy_bear (2)_aug_8.npz
# Successfully augmented and saved: gummy_bear (2)_aug_9.npz
# Successfully augmented and saved: gummy_bear (2)_aug_10.npz
# Successfully augmented and saved: gummy_bear (2)_aug_11.npz
# Successfully augmented and saved: gummy_bear (2)_aug_12.npz
# Successfully augmented and saved: gummy_bear (2)_aug_13.npz
# Successfully augmented and saved: heart_cake_aug_0.npz
# Successfully augmented and saved: heart_cake_aug_1.npz
# Successfully augmented and saved: heart_cake_aug_2.npz
# Successfully augmented and saved: heart_cake_aug_3.npz
# Successfully augmented and saved: heart_cake_aug_4.npz
# Successfully augmented and saved: heart_cake_aug_5.npz
# Successfully augmented and saved: heart_cake_aug_6.npz
# Successfully augmented and saved: heart_cake_aug_7.npz
# Successfully augmented and saved: heart_cake_aug_8.npz
# Successfully augmented and saved: heart_cake_aug_9.npz
# Successfully augmented and saved: heart_cake_aug_10.npz
# Successfully augmented and saved: heart_cake_aug_11.npz
# Successfully augmented and saved: heart_cake_aug_12.npz
# Successfully augmented and saved: heart_cake_aug_13.npz
# Successfully augmented and saved: jelly_aug_0.npz
# Successfully augmented and saved: jelly_aug_1.npz
# Successfully augmented and saved: jelly_aug_2.npz
# Successfully augmented and saved: jelly_aug_3.npz
# Successfully augmented and saved: jelly_aug_4.npz
# Successfully augmented and saved: jelly_aug_5.npz
# Successfully augmented and saved: jelly_aug_6.npz
# Successfully augmented and saved: jelly_aug_7.npz
# Successfully augmented and saved: jelly_aug_8.npz
# Successfully augmented and saved: jelly_aug_9.npz
# Successfully augmented and saved: jelly_aug_10.npz
# Successfully augmented and saved: jelly_aug_11.npz
# Successfully augmented and saved: jelly_aug_12.npz
# Successfully augmented and saved: jelly_aug_13.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_0.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_1.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_2.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_3.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_4.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_5.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_6.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_7.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_8.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_9.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_10.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_11.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_12.npz
# Successfully augmented and saved: jiggly_bunny_pudding_aug_13.npz
# Successfully augmented and saved: milkshake_my_friend_aug_0.npz
# Successfully augmented and saved: milkshake_my_friend_aug_1.npz
# Successfully augmented and saved: milkshake_my_friend_aug_2.npz
# Successfully augmented and saved: milkshake_my_friend_aug_3.npz
# Successfully augmented and saved: milkshake_my_friend_aug_4.npz
# Successfully augmented and saved: milkshake_my_friend_aug_5.npz
# Successfully augmented and saved: milkshake_my_friend_aug_6.npz
# Successfully augmented and saved: milkshake_my_friend_aug_7.npz
# Successfully augmented and saved: milkshake_my_friend_aug_8.npz
# Successfully augmented and saved: milkshake_my_friend_aug_9.npz
# Successfully augmented and saved: milkshake_my_friend_aug_10.npz
# Successfully augmented and saved: milkshake_my_friend_aug_11.npz
# Successfully augmented and saved: milkshake_my_friend_aug_12.npz
# Successfully augmented and saved: milkshake_my_friend_aug_13.npz
# Successfully augmented and saved: chocolate_pie_aug_0.npz
# Successfully augmented and saved: chocolate_pie_aug_1.npz
# Successfully augmented and saved: chocolate_pie_aug_2.npz
# Successfully augmented and saved: chocolate_pie_aug_3.npz
# Successfully augmented and saved: chocolate_pie_aug_4.npz
# Successfully augmented and saved: chocolate_pie_aug_5.npz
# Successfully augmented and saved: chocolate_pie_aug_6.npz
# Successfully augmented and saved: chocolate_pie_aug_7.npz
# Successfully augmented and saved: chocolate_pie_aug_8.npz
# Successfully augmented and saved: chocolate_pie_aug_9.npz
# Successfully augmented and saved: chocolate_pie_aug_10.npz
# Successfully augmented and saved: chocolate_pie_aug_11.npz
# Successfully augmented and saved: chocolate_pie_aug_12.npz
# Successfully augmented and saved: chocolate_pie_aug_13.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_0.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_1.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_2.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_3.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_4.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_5.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_6.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_7.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_8.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_9.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_10.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_11.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_12.npz
# Successfully augmented and saved: sugar_bunny_in_choco_aug_13.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_0.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_1.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_2.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_3.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_4.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_5.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_6.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_7.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_8.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_9.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_10.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_11.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_12.npz
# Successfully augmented and saved: ice_cream_sandwich_aug_13.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_0.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_1.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_2.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_3.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_4.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_5.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_6.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_7.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_8.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_9.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_10.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_11.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_12.npz
# Successfully augmented and saved: chocolate_cake (1)_aug_13.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_0.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_1.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_2.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_3.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_4.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_5.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_6.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_7.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_8.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_9.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_10.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_11.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_12.npz
# Successfully augmented and saved: chocolate_easter_bunny_aug_13.npz
# Successfully augmented and saved: chocolate_milkshake_aug_0.npz
# Successfully augmented and saved: chocolate_milkshake_aug_1.npz
# Successfully augmented and saved: chocolate_milkshake_aug_2.npz
# Successfully augmented and saved: chocolate_milkshake_aug_3.npz
# Successfully augmented and saved: chocolate_milkshake_aug_4.npz
# Successfully augmented and saved: chocolate_milkshake_aug_5.npz
# Successfully augmented and saved: chocolate_milkshake_aug_6.npz
# Successfully augmented and saved: chocolate_milkshake_aug_7.npz
# Successfully augmented and saved: chocolate_milkshake_aug_8.npz
# Successfully augmented and saved: chocolate_milkshake_aug_9.npz
# Successfully augmented and saved: chocolate_milkshake_aug_10.npz
# Successfully augmented and saved: chocolate_milkshake_aug_11.npz
# Successfully augmented and saved: chocolate_milkshake_aug_12.npz
# Successfully augmented and saved: chocolate_milkshake_aug_13.npz
# Successfully augmented and saved: oreo_aug_0.npz
# Successfully augmented and saved: oreo_aug_1.npz
# Successfully augmented and saved: oreo_aug_2.npz
# Successfully augmented and saved: oreo_aug_3.npz
# Successfully augmented and saved: oreo_aug_4.npz
# Successfully augmented and saved: oreo_aug_5.npz
# Successfully augmented and saved: oreo_aug_6.npz
# Successfully augmented and saved: oreo_aug_7.npz
# Successfully augmented and saved: oreo_aug_8.npz
# Successfully augmented and saved: oreo_aug_9.npz
# Successfully augmented and saved: oreo_aug_10.npz
# Successfully augmented and saved: oreo_aug_11.npz
# Successfully augmented and saved: oreo_aug_12.npz
# Successfully augmented and saved: oreo_aug_13.npz
# Successfully augmented and saved: chocolate_cocktail_aug_0.npz
# Successfully augmented and saved: chocolate_cocktail_aug_1.npz
# Successfully augmented and saved: chocolate_cocktail_aug_2.npz
# Successfully augmented and saved: chocolate_cocktail_aug_3.npz
# Successfully augmented and saved: chocolate_cocktail_aug_4.npz
# Successfully augmented and saved: chocolate_cocktail_aug_5.npz
# Successfully augmented and saved: chocolate_cocktail_aug_6.npz
# Successfully augmented and saved: chocolate_cocktail_aug_7.npz
# Successfully augmented and saved: chocolate_cocktail_aug_8.npz
# Successfully augmented and saved: chocolate_cocktail_aug_9.npz
# Successfully augmented and saved: chocolate_cocktail_aug_10.npz
# Successfully augmented and saved: chocolate_cocktail_aug_11.npz
# Successfully augmented and saved: chocolate_cocktail_aug_12.npz
# Successfully augmented and saved: chocolate_cocktail_aug_13.npz
# Successfully augmented and saved: chocolate_donut_aug_0.npz
# Successfully augmented and saved: chocolate_donut_aug_1.npz
# Successfully augmented and saved: chocolate_donut_aug_2.npz
# Successfully augmented and saved: chocolate_donut_aug_3.npz
# Successfully augmented and saved: chocolate_donut_aug_4.npz
# Successfully augmented and saved: chocolate_donut_aug_5.npz
# Successfully augmented and saved: chocolate_donut_aug_6.npz
# Successfully augmented and saved: chocolate_donut_aug_7.npz
# Successfully augmented and saved: chocolate_donut_aug_8.npz
# Successfully augmented and saved: chocolate_donut_aug_9.npz
# Successfully augmented and saved: chocolate_donut_aug_10.npz
# Successfully augmented and saved: chocolate_donut_aug_11.npz
# Successfully augmented and saved: chocolate_donut_aug_12.npz
# Successfully augmented and saved: chocolate_donut_aug_13.npz
# Successfully augmented and saved: hazelnut_twist_aug_0.npz
# Successfully augmented and saved: hazelnut_twist_aug_1.npz
# Successfully augmented and saved: hazelnut_twist_aug_2.npz
# Successfully augmented and saved: hazelnut_twist_aug_3.npz
# Successfully augmented and saved: hazelnut_twist_aug_4.npz
# Successfully augmented and saved: hazelnut_twist_aug_5.npz
# Successfully augmented and saved: hazelnut_twist_aug_6.npz
# Successfully augmented and saved: hazelnut_twist_aug_7.npz
# Successfully augmented and saved: hazelnut_twist_aug_8.npz
# Successfully augmented and saved: hazelnut_twist_aug_9.npz
# Successfully augmented and saved: hazelnut_twist_aug_10.npz
# Successfully augmented and saved: hazelnut_twist_aug_11.npz
# Successfully augmented and saved: hazelnut_twist_aug_12.npz
# Successfully augmented and saved: hazelnut_twist_aug_13.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_0.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_1.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_2.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_3.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_4.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_5.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_6.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_7.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_8.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_9.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_10.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_11.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_12.npz
# Successfully augmented and saved: chocolate_teddy_bear_aug_13.npz
# Successfully augmented and saved: ice_cream_aug_0.npz
# Successfully augmented and saved: ice_cream_aug_1.npz
# Successfully augmented and saved: ice_cream_aug_2.npz
# Successfully augmented and saved: ice_cream_aug_3.npz
# Successfully augmented and saved: ice_cream_aug_4.npz
# Successfully augmented and saved: ice_cream_aug_5.npz
# Successfully augmented and saved: ice_cream_aug_6.npz
# Successfully augmented and saved: ice_cream_aug_7.npz
# Successfully augmented and saved: ice_cream_aug_8.npz
# Successfully augmented and saved: ice_cream_aug_9.npz
# Successfully augmented and saved: ice_cream_aug_10.npz
# Successfully augmented and saved: ice_cream_aug_11.npz
# Successfully augmented and saved: ice_cream_aug_12.npz
# Successfully augmented and saved: ice_cream_aug_13.npz
# Successfully augmented and saved: gummy_bear (1)_aug_0.npz
# Successfully augmented and saved: gummy_bear (1)_aug_1.npz
# Successfully augmented and saved: gummy_bear (1)_aug_2.npz
# Successfully augmented and saved: gummy_bear (1)_aug_3.npz
# Successfully augmented and saved: gummy_bear (1)_aug_4.npz
# Successfully augmented and saved: gummy_bear (1)_aug_5.npz
# Successfully augmented and saved: gummy_bear (1)_aug_6.npz
# Successfully augmented and saved: gummy_bear (1)_aug_7.npz
# Successfully augmented and saved: gummy_bear (1)_aug_8.npz
# Successfully augmented and saved: gummy_bear (1)_aug_9.npz
# Successfully augmented and saved: gummy_bear (1)_aug_10.npz
# Successfully augmented and saved: gummy_bear (1)_aug_11.npz
# Successfully augmented and saved: gummy_bear (1)_aug_12.npz
# Successfully augmented and saved: gummy_bear (1)_aug_13.npz
# Successfully augmented and saved: chocolate_dessert_aug_0.npz
# Successfully augmented and saved: chocolate_dessert_aug_1.npz
# Successfully augmented and saved: chocolate_dessert_aug_2.npz
# Successfully augmented and saved: chocolate_dessert_aug_3.npz
# Successfully augmented and saved: chocolate_dessert_aug_4.npz
# Successfully augmented and saved: chocolate_dessert_aug_5.npz
# Successfully augmented and saved: chocolate_dessert_aug_6.npz
# Successfully augmented and saved: chocolate_dessert_aug_7.npz
# Successfully augmented and saved: chocolate_dessert_aug_8.npz
# Successfully augmented and saved: chocolate_dessert_aug_9.npz
# Successfully augmented and saved: chocolate_dessert_aug_10.npz
# Successfully augmented and saved: chocolate_dessert_aug_11.npz
# Successfully augmented and saved: chocolate_dessert_aug_12.npz
# Successfully augmented and saved: chocolate_dessert_aug_13.npz
# Successfully augmented and saved: chocolate_python_aug_0.npz
# Successfully augmented and saved: chocolate_python_aug_1.npz
# Successfully augmented and saved: chocolate_python_aug_2.npz
# Successfully augmented and saved: chocolate_python_aug_3.npz
# Successfully augmented and saved: chocolate_python_aug_4.npz
# Successfully augmented and saved: chocolate_python_aug_5.npz
# Successfully augmented and saved: chocolate_python_aug_6.npz
# Successfully augmented and saved: chocolate_python_aug_7.npz
# Successfully augmented and saved: chocolate_python_aug_8.npz
# Successfully augmented and saved: chocolate_python_aug_9.npz
# Successfully augmented and saved: chocolate_python_aug_10.npz
# Successfully augmented and saved: chocolate_python_aug_11.npz
# Successfully augmented and saved: chocolate_python_aug_12.npz
# Successfully augmented and saved: chocolate_python_aug_13.npz
# Successfully augmented and saved: strawberry_cake_aug_0.npz
# Successfully augmented and saved: strawberry_cake_aug_1.npz
# Successfully augmented and saved: strawberry_cake_aug_2.npz
# Successfully augmented and saved: strawberry_cake_aug_3.npz
# Successfully augmented and saved: strawberry_cake_aug_4.npz
# Successfully augmented and saved: strawberry_cake_aug_5.npz
# Successfully augmented and saved: strawberry_cake_aug_6.npz
# Successfully augmented and saved: strawberry_cake_aug_7.npz
# Successfully augmented and saved: strawberry_cake_aug_8.npz
# Successfully augmented and saved: strawberry_cake_aug_9.npz
# Successfully augmented and saved: strawberry_cake_aug_10.npz
# Successfully augmented and saved: strawberry_cake_aug_11.npz
# Successfully augmented and saved: strawberry_cake_aug_12.npz
# Successfully augmented and saved: strawberry_cake_aug_13.npz
# Successfully augmented and saved: break_3december_day_19_aug_0.npz
# Successfully augmented and saved: break_3december_day_19_aug_1.npz
# Successfully augmented and saved: break_3december_day_19_aug_2.npz
# Successfully augmented and saved: break_3december_day_19_aug_3.npz
# Successfully augmented and saved: break_3december_day_19_aug_4.npz
# Successfully augmented and saved: break_3december_day_19_aug_5.npz
# Successfully augmented and saved: break_3december_day_19_aug_6.npz
# Successfully augmented and saved: break_3december_day_19_aug_7.npz
# Successfully augmented and saved: break_3december_day_19_aug_8.npz
# Successfully augmented and saved: break_3december_day_19_aug_9.npz
# Successfully augmented and saved: break_3december_day_19_aug_10.npz
# Successfully augmented and saved: break_3december_day_19_aug_11.npz
# Successfully augmented and saved: break_3december_day_19_aug_12.npz
# Successfully augmented and saved: break_3december_day_19_aug_13.npz
# Successfully augmented and saved: gummy_bears_aug_0.npz
# Successfully augmented and saved: gummy_bears_aug_1.npz
# Successfully augmented and saved: gummy_bears_aug_2.npz
# Successfully augmented and saved: gummy_bears_aug_3.npz
# Successfully augmented and saved: gummy_bears_aug_4.npz
# Successfully augmented and saved: gummy_bears_aug_5.npz
# Successfully augmented and saved: gummy_bears_aug_6.npz
# Successfully augmented and saved: gummy_bears_aug_7.npz
# Successfully augmented and saved: gummy_bears_aug_8.npz
# Successfully augmented and saved: gummy_bears_aug_9.npz
# Successfully augmented and saved: gummy_bears_aug_10.npz
# Successfully augmented and saved: gummy_bears_aug_11.npz
# ...
# Successfully augmented and saved: birthday_cake_aug_11.npz
# Successfully augmented and saved: birthday_cake_aug_12.npz
# Successfully augmented and saved: birthday_cake_aug_13.npz
# Successfully augmented and saved: pastry_bear_aug_0.npz
# Successfully augmented and saved: pastry_bear_aug_1.npz
# Successfully augmented and saved: pastry_bear_aug_2.npz
# Successfully augmented and saved: pastry_bear_aug_3.npz
# Successfully augmented and saved: pastry_bear_aug_4.npz
# Successfully augmented and saved: pastry_bear_aug_5.npz
# Successfully augmented and saved: pastry_bear_aug_6.npz
# Successfully augmented and saved: pastry_bear_aug_7.npz
# Successfully augmented and saved: pastry_bear_aug_8.npz
# Successfully augmented and saved: pastry_bear_aug_9.npz
# Successfully augmented and saved: pastry_bear_aug_10.npz
# Successfully augmented and saved: pastry_bear_aug_11.npz
# Successfully augmented and saved: pastry_bear_aug_12.npz
# Successfully augmented and saved: pastry_bear_aug_13.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_0.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_1.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_2.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_3.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_4.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_5.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_6.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_7.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_8.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_9.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_10.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_11.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_12.npz
# Successfully augmented and saved: photorealistic_chocolate_milk_carton_pint_aug_13.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_0.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_1.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_2.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_3.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_4.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_5.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_6.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_7.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_8.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_9.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_10.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_11.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_12.npz
# Successfully augmented and saved: adidas_chocolate_to_my_strawberry_sneaker_aug_13.npz
# Successfully augmented and saved: vegan_icecream_aug_0.npz
# Successfully augmented and saved: vegan_icecream_aug_1.npz
# Successfully augmented and saved: vegan_icecream_aug_2.npz
# Successfully augmented and saved: vegan_icecream_aug_3.npz
# Successfully augmented and saved: vegan_icecream_aug_4.npz
# Successfully augmented and saved: vegan_icecream_aug_5.npz
# Successfully augmented and saved: vegan_icecream_aug_6.npz
# Successfully augmented and saved: vegan_icecream_aug_7.npz
# Successfully augmented and saved: vegan_icecream_aug_8.npz
# Successfully augmented and saved: vegan_icecream_aug_9.npz
# Successfully augmented and saved: vegan_icecream_aug_10.npz
# Successfully augmented and saved: vegan_icecream_aug_11.npz
# Successfully augmented and saved: vegan_icecream_aug_12.npz
# Successfully augmented and saved: vegan_icecream_aug_13.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_0.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_1.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_2.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_3.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_4.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_5.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_6.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_7.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_8.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_9.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_10.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_11.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_12.npz
# Successfully augmented and saved: chocolate_mini_cookies_aug_13.npz
# Successfully augmented and saved: gummy_bear_bull_aug_0.npz
# Successfully augmented and saved: gummy_bear_bull_aug_1.npz
# Successfully augmented and saved: gummy_bear_bull_aug_2.npz
# Successfully augmented and saved: gummy_bear_bull_aug_3.npz
# Successfully augmented and saved: gummy_bear_bull_aug_4.npz
# Successfully augmented and saved: gummy_bear_bull_aug_5.npz
# Successfully augmented and saved: gummy_bear_bull_aug_6.npz
# Successfully augmented and saved: gummy_bear_bull_aug_7.npz
# Successfully augmented and saved: gummy_bear_bull_aug_8.npz
# Successfully augmented and saved: gummy_bear_bull_aug_9.npz
# Successfully augmented and saved: gummy_bear_bull_aug_10.npz
# Successfully augmented and saved: gummy_bear_bull_aug_11.npz
# Successfully augmented and saved: gummy_bear_bull_aug_12.npz
# Successfully augmented and saved: gummy_bear_bull_aug_13.npz
# Successfully augmented and saved: cookies_3dst6_aug_0.npz
# Successfully augmented and saved: cookies_3dst6_aug_1.npz
# Successfully augmented and saved: cookies_3dst6_aug_2.npz
# Successfully augmented and saved: cookies_3dst6_aug_3.npz
# Successfully augmented and saved: cookies_3dst6_aug_4.npz
# Successfully augmented and saved: cookies_3dst6_aug_5.npz
# Successfully augmented and saved: cookies_3dst6_aug_6.npz
# Successfully augmented and saved: cookies_3dst6_aug_7.npz
# Successfully augmented and saved: cookies_3dst6_aug_8.npz
# Successfully augmented and saved: cookies_3dst6_aug_9.npz
# Successfully augmented and saved: cookies_3dst6_aug_10.npz
# Successfully augmented and saved: cookies_3dst6_aug_11.npz
# Successfully augmented and saved: cookies_3dst6_aug_12.npz
# Successfully augmented and saved: cookies_3dst6_aug_13.npz
# Successfully augmented and saved: cake_gradient_aug_0.npz
# Successfully augmented and saved: cake_gradient_aug_1.npz
# Successfully augmented and saved: cake_gradient_aug_2.npz
# Successfully augmented and saved: cake_gradient_aug_3.npz
# Successfully augmented and saved: cake_gradient_aug_4.npz
# Successfully augmented and saved: cake_gradient_aug_5.npz
# Successfully augmented and saved: cake_gradient_aug_6.npz
# Successfully augmented and saved: cake_gradient_aug_7.npz
# Successfully augmented and saved: cake_gradient_aug_8.npz
# Successfully augmented and saved: cake_gradient_aug_9.npz
# Successfully augmented and saved: cake_gradient_aug_10.npz
# Successfully augmented and saved: cake_gradient_aug_11.npz
# Successfully augmented and saved: cake_gradient_aug_12.npz
# Successfully augmented and saved: cake_gradient_aug_13.npz
# Successfully augmented and saved: gummy_bear_aug_0.npz
# Successfully augmented and saved: gummy_bear_aug_1.npz
# Successfully augmented and saved: gummy_bear_aug_2.npz
# Successfully augmented and saved: gummy_bear_aug_3.npz
# Successfully augmented and saved: gummy_bear_aug_4.npz
# Successfully augmented and saved: gummy_bear_aug_5.npz
# Successfully augmented and saved: gummy_bear_aug_6.npz
# Successfully augmented and saved: gummy_bear_aug_7.npz
# Successfully augmented and saved: gummy_bear_aug_8.npz
# Successfully augmented and saved: gummy_bear_aug_9.npz
# Successfully augmented and saved: gummy_bear_aug_10.npz
# Successfully augmented and saved: gummy_bear_aug_11.npz
# Successfully augmented and saved: gummy_bear_aug_12.npz
# Successfully augmented and saved: gummy_bear_aug_13.npz
# Successfully augmented and saved: cannoli_aug_0.npz
# Successfully augmented and saved: cannoli_aug_1.npz
# Successfully augmented and saved: cannoli_aug_2.npz
# Successfully augmented and saved: cannoli_aug_3.npz
# Successfully augmented and saved: cannoli_aug_4.npz
# Successfully augmented and saved: cannoli_aug_5.npz
# Successfully augmented and saved: cannoli_aug_6.npz
# Successfully augmented and saved: cannoli_aug_7.npz
# Successfully augmented and saved: cannoli_aug_8.npz
# Successfully augmented and saved: cannoli_aug_9.npz
# Successfully augmented and saved: cannoli_aug_10.npz
# Successfully augmented and saved: cannoli_aug_11.npz
# Successfully augmented and saved: cannoli_aug_12.npz
# Successfully augmented and saved: cannoli_aug_13.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_0.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_1.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_2.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_3.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_4.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_5.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_6.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_7.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_8.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_9.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_10.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_11.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_12.npz
# Successfully augmented and saved: banana_yellow_low_poly_asset_aug_13.npz
# Successfully augmented and saved: disco_gummy_bear_aug_0.npz
# Successfully augmented and saved: disco_gummy_bear_aug_1.npz
# Successfully augmented and saved: disco_gummy_bear_aug_2.npz
# Successfully augmented and saved: disco_gummy_bear_aug_3.npz
# Successfully augmented and saved: disco_gummy_bear_aug_4.npz
# Successfully augmented and saved: disco_gummy_bear_aug_5.npz
# Successfully augmented and saved: disco_gummy_bear_aug_6.npz
# Successfully augmented and saved: disco_gummy_bear_aug_7.npz
# Successfully augmented and saved: disco_gummy_bear_aug_8.npz
# Successfully augmented and saved: disco_gummy_bear_aug_9.npz
# Successfully augmented and saved: disco_gummy_bear_aug_10.npz
# Successfully augmented and saved: disco_gummy_bear_aug_11.npz
# Successfully augmented and saved: disco_gummy_bear_aug_12.npz
# Successfully augmented and saved: disco_gummy_bear_aug_13.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_0.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_1.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_2.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_3.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_4.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_5.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_6.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_7.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_8.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_9.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_10.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_11.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_12.npz
# Successfully augmented and saved: happy_easter_chocolate_bunny_aug_13.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_0.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_1.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_2.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_3.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_4.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_5.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_6.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_7.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_8.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_9.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_10.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_11.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_12.npz
# Successfully augmented and saved: nesquik_chocolate_milk_aug_13.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_0.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_1.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_2.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_3.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_4.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_5.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_6.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_7.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_8.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_9.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_10.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_11.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_12.npz
# Successfully augmented and saved: free_to_download_handpainted_stylized_cupcake_aug_13.npz
# Successfully augmented and saved: sliced_marble_cake_aug_0.npz
# Successfully augmented and saved: sliced_marble_cake_aug_1.npz
# Successfully augmented and saved: sliced_marble_cake_aug_2.npz
# Successfully augmented and saved: sliced_marble_cake_aug_3.npz
# Successfully augmented and saved: sliced_marble_cake_aug_4.npz
# Successfully augmented and saved: sliced_marble_cake_aug_5.npz
# Successfully augmented and saved: sliced_marble_cake_aug_6.npz
# Successfully augmented and saved: sliced_marble_cake_aug_7.npz
# Successfully augmented and saved: sliced_marble_cake_aug_8.npz
# Successfully augmented and saved: sliced_marble_cake_aug_9.npz
# Successfully augmented and saved: sliced_marble_cake_aug_10.npz
# Successfully augmented and saved: sliced_marble_cake_aug_11.npz
# Successfully augmented and saved: sliced_marble_cake_aug_12.npz
# Successfully augmented and saved: sliced_marble_cake_aug_13.npz
# Successfully augmented and saved: candy_tractor_aug_0.npz
# Successfully augmented and saved: candy_tractor_aug_1.npz
# Successfully augmented and saved: candy_tractor_aug_2.npz
# Successfully augmented and saved: candy_tractor_aug_3.npz
# Successfully augmented and saved: candy_tractor_aug_4.npz
# Successfully augmented and saved: candy_tractor_aug_5.npz
# Successfully augmented and saved: candy_tractor_aug_6.npz
# Successfully augmented and saved: candy_tractor_aug_7.npz
# Successfully augmented and saved: candy_tractor_aug_8.npz
# Successfully augmented and saved: candy_tractor_aug_9.npz
# Successfully augmented and saved: candy_tractor_aug_10.npz
# Successfully augmented and saved: candy_tractor_aug_11.npz
# Successfully augmented and saved: candy_tractor_aug_12.npz
# Successfully augmented and saved: candy_tractor_aug_13.npz

# %% [markdown]
# Split the data

# %%
import random
import shutil

tensor_directory = '/home/aalab/Desktop/tripoFT/augmented_tensors'

# Directory to save the splits
train_dir = '/home/aalab/Desktop/tripoFT/split_data/train'
val_dir = '/home/aalab/Desktop/tripoFT/split_data/val'
test_dir = '/home/aalab/Desktop/tripoFT/split_data/test'

# # Create directories if they don't exist
for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)

# Set the seed for reproducibility
random.seed(42)

# List of voxel tensor files
tensor_files = os.listdir(tensor_directory)
random.shuffle(tensor_files)

# Define the split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the number of files for each split
num_files = len(tensor_files)
num_train = int(train_ratio * num_files)
num_val = int(val_ratio * num_files)

# Split the files
train_files = tensor_files[:num_train]
val_files = tensor_files[num_train:num_train + num_val]
test_files = tensor_files[num_train + num_val:]

# Move files to respective directories
for file in train_files:
    shutil.copyfile(os.path.join(tensor_directory, file), os.path.join(train_dir, file))

for file in val_files:
    shutil.copyfile(os.path.join(tensor_directory, file), os.path.join(val_dir, file))

for file in test_files:
    shutil.copyfile(os.path.join(tensor_directory, file), os.path.join(test_dir, file))

print("Data split into train, validation, and test sets.")
print(num_files, num_train, num_val)
# Out:
# Data split into train, validation, and test sets.
# 2030 1421 304

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import numpy as np
import torch

# Load the .npz file
data = np.load('/home/aalab/Desktop/tripoFT/tensors/a_little_bite_of_france..npz')

# Iterate over the loaded arrays
for key in data:
    # Convert the NumPy array to a PyTorch tensor
    tensor = torch.tensor(data[key])
    # Check the device of the tensor
    print(f"Device of '{key}': {tensor.device}")
# Out:
# Device of 'vertices': cpu
# Device of 'faces': cpu

# %% [markdown]
# Load the Data

# %% [markdown]
# Get the TripoSR Model directory

# %% [markdown]
# Training Loop

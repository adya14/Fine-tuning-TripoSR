# %%
# %pip install torch torchvision
# %pip install trimesh numpy scipy
# Out:
# Requirement already satisfied: torch in ./myenv/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: torchvision in ./myenv/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./myenv/lib/python3.10/site-packages (from torch) (4.11.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./myenv/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./myenv/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./myenv/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: triton==2.3.0 in ./myenv/lib/python3.10/site-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./myenv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./myenv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./myenv/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./myenv/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: fsspec in ./myenv/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: filelock in ./myenv/lib/python3.10/site-packages (from torch) (3.14.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./myenv/lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./myenv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: networkx in ./myenv/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./myenv/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./myenv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: sympy in ./myenv/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: jinja2 in ./myenv/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./myenv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: numpy in ./myenv/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./myenv/lib/python3.10/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./myenv/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./myenv/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trimesh in ./myenv/lib/python3.10/site-packages (4.0.5)
# Requirement already satisfied: numpy in ./myenv/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scipy in ./myenv/lib/python3.10/site-packages (1.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import torch
import json
import trimesh
import os
import random
import shutil

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Read data

# %%
data = pd.read_csv('/home/aalab/Desktop/tripoFT/metadata.csv')

# %%
print("The first few rows of the DataFrame:")
print(data.head())

print("\nData info:")
print(data.info())

print("\nData columns:")
print(data.columns)

print("\nData described:")
print(data.describe())
# Out:
# The first few rows of the DataFrame:
#                                  filename      size  \
# 0  cadbury_dairy_milk_chocolate_piece.glb    152796
# 1          bonnie_melted_chocolate_ar.glb   8285860
# 2              chocobar_ice_cream (1).glb   4499300
# 3                           ice_cream.glb  12444648
# 4                   chocolate_truffle.glb   2084100
#
#                                          object_path
# 0  /home/aalab/Desktop/tripoFT/Dataset/cadbury_da...
# 1  /home/aalab/Desktop/tripoFT/Dataset/bonnie_mel...
# 2  /home/aalab/Desktop/tripoFT/Dataset/chocobar_i...
# 3  /home/aalab/Desktop/tripoFT/Dataset/ice_cream.glb
# 4  /home/aalab/Desktop/tripoFT/Dataset/chocolate_...
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   filename     145 non-null    object
#  1   size         145 non-null    int64
#  2   object_path  145 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.5+ KB
# None
#
# Data columns:
# Index(['filename', 'size', 'object_path'], dtype='object')
#
# Data described:
#                size
# count  1.450000e+02
# mean   1.302109e+07
# std    2.178698e+07
# min    1.987600e+04
# 25%    1.708740e+06
# 50%    5.081284e+06
# 75%    1.750160e+07
# max    1.431980e+08

# %% [markdown]
# Clean Data

# %%
data.drop_duplicates(inplace=True)

# Drop rows with missing values in specific columns
columns_with_missing_values = ['filename', 'size', 'object_path']
data.dropna(subset=columns_with_missing_values, inplace=True)

# Convert columns to appropriate data types
data['filename'] = data['filename'].astype(str)
data['size'] = data['size'].astype(str)
data['object_path'] = data['object_path'].astype(str)

# Print cleaned DataFrame
print(data)
# Out:
#                                    filename      size  \
# 0    cadbury_dairy_milk_chocolate_piece.glb    152796
# 1            bonnie_melted_chocolate_ar.glb   8285860
# 2                chocobar_ice_cream (1).glb   4499300
# 3                             ice_cream.glb  12444648
# 4                     chocolate_truffle.glb   2084100
# ..                                      ...       ...
# 140                     strawberry_cake.glb  25159596
# 141                jiggly_bunny_pudding.glb   1026416
# 142            kitchen_sink_fiesta_5149.glb  26103980
# 143   easter_egg_2024_marbled_chocolate.glb   3743544
# 144              paleta_payaso_lollypop.glb    439920
#
#                                            object_path
# 0    /home/aalab/Desktop/tripoFT/Dataset/cadbury_da...
# 1    /home/aalab/Desktop/tripoFT/Dataset/bonnie_mel...
# 2    /home/aalab/Desktop/tripoFT/Dataset/chocobar_i...
# 3    /home/aalab/Desktop/tripoFT/Dataset/ice_cream.glb
# 4    /home/aalab/Desktop/tripoFT/Dataset/chocolate_...
# ..                                                 ...
# 140  /home/aalab/Desktop/tripoFT/Dataset/strawberry...
# 141  /home/aalab/Desktop/tripoFT/Dataset/jiggly_bun...
# 142  /home/aalab/Desktop/tripoFT/Dataset/kitchen_si...
# 143  /home/aalab/Desktop/tripoFT/Dataset/easter_egg...
# 144  /home/aalab/Desktop/tripoFT/Dataset/paleta_pay...
#
# [145 rows x 3 columns]

# %% [markdown]
# Convert 3D Objects into a Usable Format that our model can work with, such as voxel grids.

# %%
import os
import numpy as np
import trimesh

def convert_glb_to_tensors(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop over all .glb files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.glb'):
            # Load the .glb file using trimesh
            file_path = os.path.join(input_folder, file_name)
            mesh = trimesh.load(file_path, force='mesh')

            # Extract vertices and faces
            vertices = mesh.vertices
            faces = mesh.faces

            # Combine vertices and faces into a single tensor
            combined_tensor = {
                'vertices': vertices,
                'faces': faces
            }

            # Save the tensor to a .npz file
            tensor_file_name = file_name.replace('.glb', '.npz')
            tensor_file_path = os.path.join(output_folder, tensor_file_name)
            np.savez(tensor_file_path, **combined_tensor)

            print(f'Successfully processed and saved: {tensor_file_name}')

input_folder = '/home/aalab/Desktop/tripoFT/Dataset'
output_folder = '/home/aalab/Desktop/tripoFT/tensors'
convert_glb_to_tensors(input_folder, output_folder)
# Out:
# Successfully processed and saved: cadbury_dairy_milk_chocolate_piece.npz
# Successfully processed and saved: bonnie_melted_chocolate_ar.npz
# Successfully processed and saved: chocobar_ice_cream (1).npz
# Successfully processed and saved: ice_cream.npz
# Successfully processed and saved: chocolate_truffle.npz
# Successfully processed and saved: oreo.npz
# Successfully processed and saved: heart_cake.npz
# Successfully processed and saved: candy_vending_machine.npz
# Successfully processed and saved: gummy_bear_bull.npz
# Successfully processed and saved: valentines_heart.npz
# Successfully processed and saved: beardpapas_smores_puff__scan.npz
# Successfully processed and saved: doughnut_pack.npz
# Successfully processed and saved: cc0_-_candies.npz
# Successfully processed and saved: biscuit.npz
# Successfully processed and saved: hot_fudge_warmer.npz
# Successfully processed and saved: chocolate_milkshake.npz
# Successfully processed and saved: vegan_icecream.npz
# Successfully processed and saved: power_shake_chocolate.npz
# Successfully processed and saved: adidas_chocolate_to_my_strawberry_sneaker.npz
# Successfully processed and saved: ferrero_rocher.npz
# Successfully processed and saved: ice_cream_sandwich.npz
# Successfully processed and saved: blue_mm_without_eyes (1).npz
# Successfully processed and saved: worlds_last_choco_taco.npz
# Successfully processed and saved: chocolate_python.npz
# Successfully processed and saved: krispy_kreme_twix_bar_doughnut.npz
# Successfully processed and saved: christmas_cookie_.rawscan..npz
# Successfully processed and saved: lindt_gold_easter_bunny.npz
# Successfully processed and saved: fluid_simulation.npz
# Successfully processed and saved: ice-cream.npz
# Successfully processed and saved: candy_tractor.npz
# Successfully processed and saved: free_to_download_handpainted_stylized_cupcake.npz
# Successfully processed and saved: paper_cup_perfect.npz
# Successfully processed and saved: chocolate_muffin.npz
# Successfully processed and saved: chocolate_waffles.npz
# Successfully processed and saved: banana_yellow_low_poly_asset.npz
# Successfully processed and saved: chocolate_cake (1).npz
# Successfully processed and saved: walshbear.npz
# Successfully processed and saved: chocolate_dessert.npz
# Successfully processed and saved: s00002_brownie_2.npz
# Successfully processed and saved: the_simpsons_game_2007_-_chocolate_bunny.npz
# Successfully processed and saved: cup_cake.npz
# Successfully processed and saved: strawberry_cake_low_poly.npz
# Successfully processed and saved: chocolates_etagere_-_decoration.npz
# Successfully processed and saved: sundae_-_sketchfab_low_poly_challenge_desserts.npz
# Successfully processed and saved: cookies_3dst6.npz
# Successfully processed and saved: sugar_bunny_in_choco.npz
# Successfully processed and saved: kinder_surprise_egg.npz
# Successfully processed and saved: gummy_bear (1).npz
# Successfully processed and saved: chocolate_berry_cake.npz
# Successfully processed and saved: hugs_kisses__cookies.npz
# Successfully processed and saved: cupcake.npz
# Successfully processed and saved: chocolate_donut_3d_scan_free.npz
# Successfully processed and saved: saint_nicholas_boot.npz
# Successfully processed and saved: hershey_chocolate_syrup.npz
# Successfully processed and saved: italian_chocolates.npz
# Successfully processed and saved: florentiner.npz
# Successfully processed and saved: hazelnut_twist.npz
# Successfully processed and saved: chocolate_mini_cookies.npz
# Successfully processed and saved: cutie_cupcake.npz
# Successfully processed and saved: happy_easter_chocolate_bunny.npz
# Successfully processed and saved: chocolate_starbucks_muffin.npz
# Successfully processed and saved: harry_potter_official_chocolate_frog_box.npz
# Successfully processed and saved: sliced_marble_cake.npz
# Successfully processed and saved: jelly.npz
# Successfully processed and saved: chocolate.npz
# Successfully processed and saved: break_3december_day_19.npz
# Successfully processed and saved: mobile_-_gummy_bear_runner_-_santa_hat.npz
# Successfully processed and saved: melting_heart.npz
# Successfully processed and saved: pink_donut_with_sprinkles.npz
# Successfully processed and saved: gummy_bear_gummibar_model.npz
# Successfully processed and saved: gummy_bear (2).npz
# Successfully processed and saved: mug-o-otterlatte.npz
# Successfully processed and saved: disco_gummy_bear.npz
# Successfully processed and saved: dreamy_chocolate_surprise.npz
# Successfully processed and saved: chocolate_mousse_cake.npz
# Successfully processed and saved: simple_chocolate_bar.npz
# Successfully processed and saved: chocolate_bars.npz
# Successfully processed and saved: schokokuchen_lina_2024.npz
# Successfully processed and saved: chocolates.npz
# Successfully processed and saved: low-poly_chocolate_bar.npz
# Successfully processed and saved: tim_tam.npz
# Successfully processed and saved: nestle_crunch_bar.npz
# Successfully processed and saved: chocolate_cake.npz
# Successfully processed and saved: lava_cake.npz
# Successfully processed and saved: a_little_bite_of_france..npz
# Successfully processed and saved: sofa.npz
# Successfully processed and saved: 18th_century_chocolate_bar.npz
# Successfully processed and saved: chocolate_frog.npz
# Successfully processed and saved: dark_chocolate_syrup.npz
# Successfully processed and saved: milkshake_my_friend.npz
# Successfully processed and saved: long_donut.npz
# Successfully processed and saved: hazelnuts_chocolate_bar.npz
# Successfully processed and saved: chocobar_ice_cream.npz
# Successfully processed and saved: blue_mm_without_eyes.npz
# Successfully processed and saved: ketchup.npz
# Successfully processed and saved: cannoli.npz
# Successfully processed and saved: hot_chocolate_with_whipped_cream.npz
# Successfully processed and saved: photorealistic_chocolate_milk_carton_pint.npz
# Successfully processed and saved: metamorphosis_chocolate_-_wavy.npz
# Successfully processed and saved: easter_bunny_cupcake.npz
# Successfully processed and saved: coffee_crisp.npz
# Successfully processed and saved: birthday_cake.npz
# Successfully processed and saved: chocolate_cupcake.npz
# Successfully processed and saved: chocolate_easter_bunny.npz
# Successfully processed and saved: brownie_square.npz
# Successfully processed and saved: cake_gradient.npz
# Successfully processed and saved: chocolate_cookies.npz
# Successfully processed and saved: kawai_ice-cream.npz
# Successfully processed and saved: chocolate_donut.npz
# Successfully processed and saved: white_chocolate_cake.npz
# Successfully processed and saved: ferrero_rocher__chocolate.npz
# Successfully processed and saved: chocolate_hedgehog.npz
# Successfully processed and saved: chocolate_easter_bunny (1).npz
# Successfully processed and saved: the_meadows_arctic_swirl_frozen_custard_dessert.npz
# Successfully processed and saved: chocolate_buttercream_cupcake.npz
# Successfully processed and saved: valentines_chocolate_heart.npz
# Successfully processed and saved: ice_cream (1).npz
# Successfully processed and saved: pancakes_low_poly_model.npz
# Successfully processed and saved: chocolate_muffin_game_ready__2k_pbr.npz
# Successfully processed and saved: nesquik_chocolate_milk.npz
# Successfully processed and saved: paleta_payaso.npz
# Successfully processed and saved: lindt_gold_chocolate_bunny.npz
# Successfully processed and saved: donut.npz
# Successfully processed and saved: low_poly_chocolate_bar.npz
# Successfully processed and saved: pastry_bear.npz
# Successfully processed and saved: candy_crush_bomba_de_color.npz
# Successfully processed and saved: gummy_bears.npz
# Successfully processed and saved: chocolate_cocktail.npz
# Successfully processed and saved: cake.npz
# Successfully processed and saved: chocolate_boy.npz
# Successfully processed and saved: chocolate_muffin_school_project.npz
# Successfully processed and saved: nutella_jar_of_chocolate.npz
# Successfully processed and saved: chocolate_pie.npz
# Successfully processed and saved: 3december_choco_cake.npz
# Successfully processed and saved: ice_cream_in_marble_bowl.npz
# Successfully processed and saved: gummy_bear.npz
# Successfully processed and saved: chocolate_teddy_bear.npz
# Successfully processed and saved: lcm_rice_crispy_treat.npz
# Successfully processed and saved: hershey_kiss.npz
# Successfully processed and saved: hot_chocolate.npz
# Successfully processed and saved: strawberry_cake.npz
# Successfully processed and saved: jiggly_bunny_pudding.npz
# Successfully processed and saved: kitchen_sink_fiesta_5149.npz
# Successfully processed and saved: easter_egg_2024_marbled_chocolate.npz
# Successfully processed and saved: paleta_payaso_lollypop.npz

# %%
import os
import numpy as np

def view_tensor_shapes(folder_path):
    # Loop over all .npz files in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.npz'):
            file_path = os.path.join(folder_path, file_name)
            
            # Load the tensor from the .npz file
            tensor_data = np.load(file_path)
            vertices = tensor_data['vertices']
            faces = tensor_data['faces']
            
            # Print the shapes of the vertices and faces
            print(f"File: {file_name}")
            print(f"  Vertices shape: {vertices.shape}")
            print(f"  Faces shape: {faces.shape}\n")

# Path to the folder containing the .npz files
folder_path = '/home/aalab/Desktop/tripoFT/tensors'
view_tensor_shapes(folder_path)
# Out:
# File: cup_cake.npz
#   Vertices shape: (4741, 3)
#   Faces shape: (8862, 3)
#
# File: brownie_square.npz
#   Vertices shape: (25260, 3)
#   Faces shape: (48314, 3)
#
# File: ice_cream (1).npz
#   Vertices shape: (499, 3)
#   Faces shape: (528, 3)
#
# File: schokokuchen_lina_2024.npz
#   Vertices shape: (15420, 3)
#   Faces shape: (24999, 3)
#
# File: hot_chocolate_with_whipped_cream.npz
#   Vertices shape: (820, 3)
#   Faces shape: (416, 3)
#
# File: doughnut_pack.npz
#   Vertices shape: (2980976, 3)
#   Faces shape: (993662, 3)
#
# File: simple_chocolate_bar.npz
#   Vertices shape: (949, 3)
#   Faces shape: (1304, 3)
#
# File: hershey_kiss.npz
#   Vertices shape: (700, 3)
#   Faces shape: (1208, 3)
#
# File: chocobar_ice_cream.npz
#   Vertices shape: (7509, 3)
#   Faces shape: (8592, 3)
#
# File: strawberry_cake_low_poly.npz
#   Vertices shape: (296, 3)
#   Faces shape: (398, 3)
#
# File: paper_cup_perfect.npz
#   Vertices shape: (3684, 3)
#   Faces shape: (3764, 3)
#
# File: chocolate_buttercream_cupcake.npz
#   Vertices shape: (513870, 3)
#   Faces shape: (171290, 3)
#
# File: krispy_kreme_twix_bar_doughnut.npz
#   Vertices shape: (16971, 3)
#   Faces shape: (29306, 3)
#
# File: bonnie_melted_chocolate_ar.npz
#   Vertices shape: (41569, 3)
#   Faces shape: (64920, 3)
#
# File: chocolate_cake.npz
#   Vertices shape: (1700, 3)
#   Faces shape: (1368, 3)
#
# File: lindt_gold_chocolate_bunny.npz
#   Vertices shape: (91697, 3)
#   Faces shape: (154675, 3)
#
# File: the_meadows_arctic_swirl_frozen_custard_dessert.npz
#   Vertices shape: (33250, 3)
#   Faces shape: (57215, 3)
#
# File: paleta_payaso.npz
#   Vertices shape: (19691, 3)
#   Faces shape: (35028, 3)
#
# File: blue_mm_without_eyes.npz
#   Vertices shape: (2232, 3)
#   Faces shape: (3548, 3)
#
# File: fluid_simulation.npz
#   Vertices shape: (2071974, 3)
#   Faces shape: (3819628, 3)
#
# File: cc0_-_candies.npz
#   Vertices shape: (1062, 3)
#   Faces shape: (1920, 3)
#
# File: pancakes_low_poly_model.npz
#   Vertices shape: (125, 3)
#   Faces shape: (142, 3)
#
# File: long_donut.npz
#   Vertices shape: (34331, 3)
#   Faces shape: (67116, 3)
#
# File: easter_egg_2024_marbled_chocolate.npz
#   Vertices shape: (10027, 3)
#   Faces shape: (19024, 3)
#
# File: hot_fudge_warmer.npz
#   Vertices shape: (31287, 3)
#   Faces shape: (44884, 3)
#
# File: kawai_ice-cream.npz
#   Vertices shape: (7302, 3)
#   Faces shape: (10314, 3)
#
# File: chocolate_berry_cake.npz
#   Vertices shape: (18968, 3)
#   Faces shape: (28776, 3)
#
# File: nutella_jar_of_chocolate.npz
#   Vertices shape: (757023, 3)
#   Faces shape: (999982, 3)
#
# File: kinder_surprise_egg.npz
#   Vertices shape: (126744, 3)
#   Faces shape: (142292, 3)
#
# File: lindt_gold_easter_bunny.npz
#   Vertices shape: (2016, 3)
#   Faces shape: (2756, 3)
#
# File: ferrero_rocher__chocolate.npz
#   Vertices shape: (16041, 3)
#   Faces shape: (27408, 3)
#
# File: gummy_bear (2).npz
#   Vertices shape: (17972, 3)
#   Faces shape: (29192, 3)
#
# File: heart_cake.npz
#   Vertices shape: (107033, 3)
#   Faces shape: (196608, 3)
#
# File: jelly.npz
#   Vertices shape: (19909, 3)
#   Faces shape: (32848, 3)
#
# File: jiggly_bunny_pudding.npz
#   Vertices shape: (15873, 3)
#   Faces shape: (27860, 3)
#
# File: milkshake_my_friend.npz
#   Vertices shape: (42844, 3)
#   Faces shape: (80910, 3)
#
# File: chocolate_pie.npz
#   Vertices shape: (143, 3)
#   Faces shape: (154, 3)
#
# File: sugar_bunny_in_choco.npz
#   Vertices shape: (6761, 3)
#   Faces shape: (10348, 3)
#
# File: ice_cream_sandwich.npz
#   Vertices shape: (475320, 3)
#   Faces shape: (725604, 3)
#
# File: chocolate_cake (1).npz
#   Vertices shape: (467, 3)
#   Faces shape: (550, 3)
#
# File: chocolate_easter_bunny.npz
#   Vertices shape: (4220, 3)
#   Faces shape: (8030, 3)
#
# File: chocolate_milkshake.npz
#   Vertices shape: (9218, 3)
#   Faces shape: (16992, 3)
#
# File: oreo.npz
#   Vertices shape: (28040, 3)
#   Faces shape: (43582, 3)
#
# File: chocolate_cocktail.npz
#   Vertices shape: (152232, 3)
#   Faces shape: (290646, 3)
#
# File: chocolate_donut.npz
#   Vertices shape: (55166, 3)
#   Faces shape: (100000, 3)
#
# File: hazelnut_twist.npz
#   Vertices shape: (52214, 3)
#   Faces shape: (97064, 3)
#
# File: chocolate_teddy_bear.npz
#   Vertices shape: (3287, 3)
#   Faces shape: (5552, 3)
#
# File: ice_cream.npz
#   Vertices shape: (117919, 3)
#   Faces shape: (190824, 3)
#
# File: gummy_bear (1).npz
#   Vertices shape: (189010, 3)
#   Faces shape: (222456, 3)
#
# File: chocolate_dessert.npz
#   Vertices shape: (5285, 3)
#   Faces shape: (7600, 3)
#
# File: chocolate_python.npz
#   Vertices shape: (9087, 3)
#   Faces shape: (10448, 3)
#
# File: strawberry_cake.npz
#   Vertices shape: (180659, 3)
#   Faces shape: (267207, 3)
#
# File: break_3december_day_19.npz
#   Vertices shape: (544, 3)
#   Faces shape: (608, 3)
#
# File: gummy_bears.npz
#   Vertices shape: (29436, 3)
#   Faces shape: (54336, 3)
#
# File: cadbury_dairy_milk_chocolate_piece.npz
#   Vertices shape: (480, 3)
#   Faces shape: (540, 3)
#
# File: christmas_cookie_.rawscan..npz
#   Vertices shape: (9412, 3)
#   Faces shape: (18438, 3)
#
# File: chocolate_waffles.npz
#   Vertices shape: (28638, 3)
#   Faces shape: (52008, 3)
#
# File: cutie_cupcake.npz
#   Vertices shape: (73711, 3)
#   Faces shape: (134240, 3)
#
# File: chocobar_ice_cream (1).npz
#   Vertices shape: (7509, 3)
#   Faces shape: (8592, 3)
#
# File: chocolates_etagere_-_decoration.npz
#   Vertices shape: (1224, 3)
#   Faces shape: (1196, 3)
#
# File: chocolate_cookies.npz
#   Vertices shape: (11526, 3)
#   Faces shape: (20290, 3)
#
# File: hazelnuts_chocolate_bar.npz
#   Vertices shape: (169825, 3)
#   Faces shape: (264252, 3)
#
# File: ferrero_rocher.npz
#   Vertices shape: (6681, 3)
#   Faces shape: (3272, 3)
#
# File: coffee_crisp.npz
#   Vertices shape: (117, 3)
#   Faces shape: (148, 3)
#
# File: nestle_crunch_bar.npz
#   Vertices shape: (706, 3)
#   Faces shape: (676, 3)
#
# File: saint_nicholas_boot.npz
#   Vertices shape: (10038, 3)
#   Faces shape: (17516, 3)
#
# File: cupcake.npz
#   Vertices shape: (144333, 3)
#   Faces shape: (72169, 3)
#
# File: worlds_last_choco_taco.npz
#   Vertices shape: (52270, 3)
#   Faces shape: (100000, 3)
#
# File: chocolate_easter_bunny (1).npz
#   Vertices shape: (151051, 3)
#   Faces shape: (265732, 3)
#
# File: chocolate_frog.npz
#   Vertices shape: (3389, 3)
#   Faces shape: (6456, 3)
#
# File: candy_crush_bomba_de_color.npz
#   Vertices shape: (246130, 3)
#   Faces shape: (463872, 3)
#
# File: s00002_brownie_2.npz
#   Vertices shape: (472291, 3)
#   Faces shape: (633354, 3)
#
# File: ice_cream_in_marble_bowl.npz
#   Vertices shape: (42853, 3)
#   Faces shape: (79424, 3)
#
# File: low-poly_chocolate_bar.npz
#   Vertices shape: (441, 3)
#   Faces shape: (310, 3)
#
# File: pink_donut_with_sprinkles.npz
#   Vertices shape: (1570206, 3)
#   Faces shape: (1442240, 3)
#
# File: the_simpsons_game_2007_-_chocolate_bunny.npz
#   Vertices shape: (3780, 3)
#   Faces shape: (3786, 3)
#
# File: hugs_kisses__cookies.npz
#   Vertices shape: (13956, 3)
#   Faces shape: (25824, 3)
#
# File: power_shake_chocolate.npz
#   Vertices shape: (11000, 3)
#   Faces shape: (15320, 3)
#
# File: chocolate_starbucks_muffin.npz
#   Vertices shape: (50540, 3)
#   Faces shape: (91270, 3)
#
# File: chocolate_muffin_game_ready__2k_pbr.npz
#   Vertices shape: (281, 3)
#   Faces shape: (480, 3)
#
# File: tim_tam.npz
#   Vertices shape: (18434, 3)
#   Faces shape: (36864, 3)
#
# File: hot_chocolate.npz
#   Vertices shape: (32688, 3)
#   Faces shape: (64177, 3)
#
# File: donut.npz
#   Vertices shape: (422510, 3)
#   Faces shape: (818304, 3)
#
# File: ketchup.npz
#   Vertices shape: (60975, 3)
#   Faces shape: (64732, 3)
#
# File: mug-o-otterlatte.npz
#   Vertices shape: (16750, 3)
#   Faces shape: (26960, 3)
#
# File: chocolate_bars.npz
#   Vertices shape: (483, 3)
#   Faces shape: (273, 3)
#
# File: 18th_century_chocolate_bar.npz
#   Vertices shape: (34445, 3)
#   Faces shape: (65082, 3)
#
# File: florentiner.npz
#   Vertices shape: (48537, 3)
#   Faces shape: (49994, 3)
#
# File: chocolate_muffin_school_project.npz
#   Vertices shape: (483, 3)
#   Faces shape: (538, 3)
#
# File: chocolates.npz
#   Vertices shape: (83864, 3)
#   Faces shape: (151488, 3)
#
# File: gummy_bear_gummibar_model.npz
#   Vertices shape: (16381, 3)
#   Faces shape: (29561, 3)
#
# File: lcm_rice_crispy_treat.npz
#   Vertices shape: (29735, 3)
#   Faces shape: (54026, 3)
#
# File: chocolate.npz
#   Vertices shape: (387919, 3)
#   Faces shape: (542042, 3)
#
# File: sundae_-_sketchfab_low_poly_challenge_desserts.npz
#   Vertices shape: (5536, 3)
#   Faces shape: (9333, 3)
#
# File: dreamy_chocolate_surprise.npz
#   Vertices shape: (7089, 3)
#   Faces shape: (8174, 3)
#
# File: chocolate_mousse_cake.npz
#   Vertices shape: (91680, 3)
#   Faces shape: (132312, 3)
#
# File: sofa.npz
#   Vertices shape: (19099, 3)
#   Faces shape: (34504, 3)
#
# File: cake.npz
#   Vertices shape: (61144, 3)
#   Faces shape: (92496, 3)
#
# File: mobile_-_gummy_bear_runner_-_santa_hat.npz
#   Vertices shape: (332, 3)
#   Faces shape: (588, 3)
#
# File: ice-cream.npz
#   Vertices shape: (19365, 3)
#   Faces shape: (36352, 3)
#
# File: metamorphosis_chocolate_-_wavy.npz
#   Vertices shape: (15069, 3)
#   Faces shape: (29418, 3)
#
# File: chocolate_donut_3d_scan_free.npz
#   Vertices shape: (933, 3)
#   Faces shape: (1000, 3)
#
# File: valentines_chocolate_heart.npz
#   Vertices shape: (151286, 3)
#   Faces shape: (242136, 3)
#
# File: valentines_heart.npz
#   Vertices shape: (1867, 3)
#   Faces shape: (2654, 3)
#
# File: paleta_payaso_lollypop.npz
#   Vertices shape: (7908, 3)
#   Faces shape: (14968, 3)
#
# File: hershey_chocolate_syrup.npz
#   Vertices shape: (3255, 3)
#   Faces shape: (6076, 3)
#
# File: biscuit.npz
#   Vertices shape: (24642, 3)
#   Faces shape: (46532, 3)
#
# File: white_chocolate_cake.npz
#   Vertices shape: (110862, 3)
#   Faces shape: (193062, 3)
#
# File: harry_potter_official_chocolate_frog_box.npz
#   Vertices shape: (13291, 3)
#   Faces shape: (19998, 3)
#
# File: chocolate_boy.npz
#   Vertices shape: (362577, 3)
#   Faces shape: (700080, 3)
#
# File: melting_heart.npz
#   Vertices shape: (3116, 3)
#   Faces shape: (6138, 3)
#
# File: chocolate_hedgehog.npz
#   Vertices shape: (51813, 3)
#   Faces shape: (100000, 3)
#
# File: lava_cake.npz
#   Vertices shape: (57250, 3)
#   Faces shape: (100000, 3)
#
# File: chocolate_truffle.npz
#   Vertices shape: (2424, 3)
#   Faces shape: (4164, 3)
#
# File: a_little_bite_of_france..npz
#   Vertices shape: (268985, 3)
#   Faces shape: (439816, 3)
#
# File: blue_mm_without_eyes (1).npz
#   Vertices shape: (2232, 3)
#   Faces shape: (3548, 3)
#
# File: beardpapas_smores_puff__scan.npz
#   Vertices shape: (41139, 3)
#   Faces shape: (81193, 3)
#
# File: 3december_choco_cake.npz
#   Vertices shape: (19712, 3)
#   Faces shape: (30806, 3)
#
# File: chocolate_cupcake.npz
#   Vertices shape: (4439, 3)
#   Faces shape: (6453, 3)
#
# File: italian_chocolates.npz
#   Vertices shape: (332190, 3)
#   Faces shape: (412472, 3)
#
# File: low_poly_chocolate_bar.npz
#   Vertices shape: (8944, 3)
#   Faces shape: (16200, 3)
#
# File: walshbear.npz
#   Vertices shape: (3287, 3)
#   Faces shape: (5552, 3)
#
# File: dark_chocolate_syrup.npz
#   Vertices shape: (4440, 3)
#   Faces shape: (5532, 3)
#
# File: kitchen_sink_fiesta_5149.npz
#   Vertices shape: (135671, 3)
#   Faces shape: (232889, 3)
#
# File: candy_vending_machine.npz
#   Vertices shape: (261427, 3)
#   Faces shape: (252018, 3)
#
# File: chocolate_muffin.npz
#   Vertices shape: (88690, 3)
#   Faces shape: (142938, 3)
#
# File: easter_bunny_cupcake.npz
#   Vertices shape: (2998, 3)
#   Faces shape: (3868, 3)
#
# File: birthday_cake.npz
#   Vertices shape: (68396, 3)
#   Faces shape: (92117, 3)
#
# File: pastry_bear.npz
#   Vertices shape: (3287, 3)
#   Faces shape: (5552, 3)
#
# File: photorealistic_chocolate_milk_carton_pint.npz
#   Vertices shape: (21534, 3)
#   Faces shape: (38252, 3)
#
# File: adidas_chocolate_to_my_strawberry_sneaker.npz
#   Vertices shape: (16129, 3)
#   Faces shape: (24864, 3)
#
# File: vegan_icecream.npz
#   Vertices shape: (344870, 3)
#   Faces shape: (647936, 3)
#
# File: chocolate_mini_cookies.npz
#   Vertices shape: (1074, 3)
#   Faces shape: (1380, 3)
#
# File: gummy_bear_bull.npz
#   Vertices shape: (1636, 3)
#   Faces shape: (2936, 3)
#
# File: cookies_3dst6.npz
#   Vertices shape: (6064, 3)
#   Faces shape: (9712, 3)
#
# File: cake_gradient.npz
#   Vertices shape: (8849, 3)
#   Faces shape: (16609, 3)
#
# File: gummy_bear.npz
#   Vertices shape: (4409, 3)
#   Faces shape: (8442, 3)
#
# File: cannoli.npz
#   Vertices shape: (52936, 3)
#   Faces shape: (100000, 3)
#
# File: banana_yellow_low_poly_asset.npz
#   Vertices shape: (403, 3)
#   Faces shape: (620, 3)
#
# File: disco_gummy_bear.npz
#   Vertices shape: (115080, 3)
#   Faces shape: (57540, 3)
#
# File: happy_easter_chocolate_bunny.npz
#   Vertices shape: (411775, 3)
#   Faces shape: (681100, 3)
#
# File: nesquik_chocolate_milk.npz
#   Vertices shape: (11153, 3)
#   Faces shape: (12024, 3)
#
# File: free_to_download_handpainted_stylized_cupcake.npz
#   Vertices shape: (2288, 3)
#   Faces shape: (2656, 3)
#
# File: sliced_marble_cake.npz
#   Vertices shape: (47396, 3)
#   Faces shape: (85510, 3)
#
# File: candy_tractor.npz
#   Vertices shape: (18651, 3)
#   Faces shape: (27684, 3)

# %% [markdown]
# Data Augmentation

# %%
# import os
# import numpy as np
# import trimesh
# import random

# def augment_vertices(vertices):
#     """Apply random transformations to the vertices."""
#     # Random rotation
#     angle = np.random.uniform(0, 2 * np.pi)
#     axis = np.random.uniform(-1, 1, 3)
#     axis /= np.linalg.norm(axis)
#     rotation_matrix = trimesh.transformations.rotation_matrix(angle, axis)[:3, :3]
    
#     # Random scaling
#     scale = np.random.uniform(0.9, 1.1)
    
#     # Random translation
#     translation = np.random.uniform(-0.1, 0.1, 3)
    
#     # Apply transformations
#     vertices = vertices @ rotation_matrix.T
#     vertices *= scale
#     vertices += translation
    
#     return vertices

# def augment_and_save_files(input_folder, output_folder, num_augmentations=5):
#     # Create the output folder if it doesn't exist
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)

#     # Loop over all .npz files in the input folder
#     for file_name in os.listdir(input_folder):
#         if file_name.endswith('.npz'):
#             file_path = os.path.join(input_folder, file_name)
#             tensor_data = np.load(file_path)
#             vertices = tensor_data['vertices']
#             faces = tensor_data['faces']
            
#             for i in range(num_augmentations):
#                 # Apply augmentation
#                 augmented_vertices = augment_vertices(vertices)
                
#                 # Combine vertices and faces into a single tensor
#                 augmented_tensor = {
#                     'vertices': augmented_vertices,
#                     'faces': faces
#                 }
                
#                 # Save the augmented tensor to a .npz file
#                 augmented_file_name = file_name.replace('.npz', f'_augmented_{i}.npz')
#                 augmented_file_path = os.path.join(output_folder, augmented_file_name)
#                 np.savez(augmented_file_path, **augmented_tensor)
                
#                 print(f'Successfully augmented and saved: {augmented_file_name}')

# input_folder = '/home/aalab/Desktop/tripoFT/tensors'
# output_folder = '/home/aalab/Desktop/tripoFT/augmented_data'
# augment_and_save_files(input_folder, output_folder)

# %% [markdown]
# Split the data

# %%
tensor_directory = '/home/aalab/Desktop/tripoFT/tensors'

# Directory to save the splits
train_dir = '/home/aalab/Desktop/tripoFT/split_data/train'
val_dir = '/home/aalab/Desktop/tripoFT/split_data/val'
test_dir = '/home/aalab/Desktop/tripoFT/split_data/test'

# # Create directories if they don't exist
for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)

# Set the seed for reproducibility
random.seed(42)

# List of voxel tensor files
tensor_files = os.listdir(tensor_directory)
random.shuffle(tensor_files)

# Define the split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the number of files for each split
num_files = len(tensor_files)
num_train = int(train_ratio * num_files)
num_val = int(val_ratio * num_files)

# Split the files
train_files = tensor_files[:num_train]
val_files = tensor_files[num_train:num_train + num_val]
test_files = tensor_files[num_train + num_val:]

# Move files to respective directories
for file in train_files:
    shutil.copyfile(os.path.join(tensor_directory, file), os.path.join(train_dir, file))

for file in val_files:
    shutil.copyfile(os.path.join(tensor_directory, file), os.path.join(val_dir, file))

for file in test_files:
    shutil.copyfile(os.path.join(tensor_directory, file), os.path.join(test_dir, file))

print("Data split into train, validation, and test sets.")
print(num_files, num_train, num_val)
# Out:
# Data split into train, validation, and test sets.
# 145 101 21

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import numpy as np
import torch

# Load the .npz file
data = np.load('/home/aalab/Desktop/tripoFT/tensors/a_little_bite_of_france..npz')

# Iterate over the loaded arrays
for key in data:
    # Convert the NumPy array to a PyTorch tensor
    tensor = torch.tensor(data[key])
    # Check the device of the tensor
    print(f"Device of '{key}': {tensor.device}")
# Out:
# Device of 'vertices': cpu
# Device of 'faces': cpu

# %% [markdown]
# Load the Data

# %% [markdown]
# Get the TripoSR Model directory

# %% [markdown]
# Training Loop
